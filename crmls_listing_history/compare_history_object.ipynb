# %% [markdown]
# # Comparing the Date-Price Pair Approach to the HISTORY Object Approach for Generating CRMLS Listing Histories
# The purpose of this notebook is to generate listing histories for a sample of listings and HISTORY objects in order to compare the results of the two methods and evaluate the accuracy of the date-pair approach.

# %%
import pandas as pd
from tqdm.notebook import tqdm
from datetime import datetime, timedelta

# %% [markdown]
# ## Reading in Samples

# %%
history_sample = pd.read_csv('data/history_sample_1017.csv')
history_sample.head()
# Out:
#    new_value      field_name  history_key modification_timestamp  \
# 0          H  STANDARDSTATUS      9999999    2020-02-24 10:27:40
# 1     270405       LISTPRICE      9999998    2020-02-24 10:15:54
# 2          S  STANDARDSTATUS      9999997    2020-02-24 10:16:21
# 3  225000.00       LISTPRICE      9999996    2020-02-24 10:25:09
# 4     539900       LISTPRICE      9999995    2020-02-24 10:16:36
#
#    resource_record_key
# 0            363940030
# 1            363882069
# 2            363822160
# 3            363798709
# 4            363747921

# %%
print(history_sample['resource_record_key'].nunique())
# get listing keys to pull all listings that are in this sample
history_sample['resource_record_key'].drop_duplicates().to_csv('data/listing_keys.csv', index=False)
# Out:
# 376457

# %%
listings_sample = pd.read_csv('data/crmls_listings_sample1.csv')

# %%
print(listings_sample.shape)
for i in range(2,13):
    listings_sample = pd.concat([listings_sample, pd.read_csv(f'data/crmls_listings_sample{i}.csv')])
# Out:
# (32560, 19)

# %%
listings_sample.shape
# Out:
# (337904, 19)

# %%
listings_sample.head()
# Out:
#    source_id  close_date expiration_date listing_contract_date  \
# 0   10002014  2015-10-27      2016-04-28            2015-06-24
# 1  100198211  2017-05-07      2017-06-30            2017-03-01
# 2   10025396         NaN      2020-06-30            2015-06-28
# 3   10025573         NaN      2020-06-30            2015-06-28
# 4   10051516  2016-02-23      2016-02-29            2015-07-04
#
#   purchase_contract_date withdrawn_date  list_price  current_price  \
# 0             2015-07-17            NaN    219900.0       220000.0
# 1             2017-04-27            NaN      2350.0         2350.0
# 2                    NaN     2020-02-24   8750000.0      8750000.0
# 3                    NaN     2020-02-24   5300000.0      5300000.0
# 4             2016-01-08            NaN    245000.0       240000.0
#
#    original_list_price  close_price price_change_timestamp status  \
# 0             219900.0     220000.0                    NaN      S
# 1               2350.0       2350.0    2017-03-22 20:27:45      S
# 2           12500000.0          NaN    2017-12-02 10:46:26      X
# 3            6200000.0          NaN    2017-12-02 10:52:23      X
# 4             265000.0     240000.0    2015-08-19 18:49:13      S
#
#    previous_list_price previous_status status_change_timestamp on_market_date  \
# 0                  NaN               P     2015-10-27 17:23:41     2015-06-24
# 1                  NaN               U     2017-05-07 19:48:00     2017-03-01
# 2           12500000.0               W     2020-07-01 00:04:17     2015-06-28
# 3            6200000.0               W     2020-07-01 01:04:19     2015-06-28
# 4             249900.0               U     2016-02-25 14:40:27     2015-07-04
#
#   off_market_date contingent_date original_entry_timestamp
# 0      2015-07-17             NaN      2015-06-24 07:56:16
# 1      2017-05-07             NaN      2017-03-22 20:27:45
# 2      2020-02-24             NaN      2015-06-28 11:00:14
# 3      2020-02-24             NaN      2015-06-28 12:10:16
# 4      2016-02-23             NaN      2015-07-04 20:25:01

# %%
history_sample.head()
# Out:
#    new_value      field_name  history_key modification_timestamp  \
# 0          H  STANDARDSTATUS      9999999    2020-02-24 10:27:40
# 1     270405       LISTPRICE      9999998    2020-02-24 10:15:54
# 2          S  STANDARDSTATUS      9999997    2020-02-24 10:16:21
# 3  225000.00       LISTPRICE      9999996    2020-02-24 10:25:09
# 4     539900       LISTPRICE      9999995    2020-02-24 10:16:36
#
#    resource_record_key
# 0            363940030
# 1            363882069
# 2            363822160
# 3            363798709
# 4            363747921

# %% [markdown]
# ## Housekeeping Functions/Objects

# %%
event_codes = { 
                'C': 50,
                'A': 100,
                'B': 200,
                'U': 240,
                'P': 240,
                'X': 300,
                'S': 500,
                'H': 640,
                'K': 620,
                'W': 600,
                'Z': 600
              }

# %%
def coalesce(*values):
    """Return the first non-None value or None if all values are None"""
    return next((v for v in values if pd.notna(v)), None)

# %%
listings_sample.columns
# Out:
# Index(['source_id', 'close_date', 'expiration_date', 'listing_contract_date',
#        'purchase_contract_date', 'withdrawn_date', 'list_price',
#        'current_price', 'original_list_price', 'close_price',
#        'price_change_timestamp', 'status', 'previous_list_price',
#        'previous_status', 'status_change_timestamp', 'on_market_date',
#        'off_market_date', 'contingent_date', 'original_entry_timestamp'],
#       dtype='object')

# %%
listings_sample.head()
# Out:
#    source_id  close_date expiration_date listing_contract_date  \
# 0   10002014  2015-10-27      2016-04-28            2015-06-24
# 1  100198211  2017-05-07      2017-06-30            2017-03-01
# 2   10025396         NaN      2020-06-30            2015-06-28
# 3   10025573         NaN      2020-06-30            2015-06-28
# 4   10051516  2016-02-23      2016-02-29            2015-07-04
#
#   purchase_contract_date withdrawn_date  list_price  current_price  \
# 0             2015-07-17            NaN    219900.0       220000.0
# 1             2017-04-27            NaN      2350.0         2350.0
# 2                    NaN     2020-02-24   8750000.0      8750000.0
# 3                    NaN     2020-02-24   5300000.0      5300000.0
# 4             2016-01-08            NaN    245000.0       240000.0
#
#    original_list_price  close_price price_change_timestamp status  \
# 0             219900.0     220000.0                    NaN      S
# 1               2350.0       2350.0    2017-03-22 20:27:45      S
# 2           12500000.0          NaN    2017-12-02 10:46:26      X
# 3            6200000.0          NaN    2017-12-02 10:52:23      X
# 4             265000.0     240000.0    2015-08-19 18:49:13      S
#
#    previous_list_price previous_status status_change_timestamp on_market_date  \
# 0                  NaN               P     2015-10-27 17:23:41     2015-06-24
# 1                  NaN               U     2017-05-07 19:48:00     2017-03-01
# 2           12500000.0               W     2020-07-01 00:04:17     2015-06-28
# 3            6200000.0               W     2020-07-01 01:04:19     2015-06-28
# 4             249900.0               U     2016-02-25 14:40:27     2015-07-04
#
#   off_market_date contingent_date original_entry_timestamp
# 0      2015-07-17             NaN      2015-06-24 07:56:16
# 1      2017-05-07             NaN      2017-03-22 20:27:45
# 2      2020-02-24             NaN      2015-06-28 11:00:14
# 3      2020-02-24             NaN      2015-06-28 12:10:16
# 4      2016-02-23             NaN      2015-07-04 20:25:01

# %% [markdown]
# ## Creating Events from Listing
# aka date-price pair approach

# %%
def create_pairs(close_date, expiration_date, listing_contract_date,
                 purchase_contract_date, list_price, current_price, 
                 original_list_price, close_price):
        """Based on which variables are present/not null, create events from date-price pairs

        Returns:
            list: list of events
        """
        pairs = []
        if type(listing_contract_date) == str:
            pairs.append((100, listing_contract_date, coalesce(original_list_price, list_price, current_price)))
        if type(purchase_contract_date) == str:
            pairs.append((240, purchase_contract_date, coalesce(current_price, list_price, current_price)))
        if type(expiration_date) == str:
            pairs.append((300, expiration_date, coalesce(current_price, list_price)))
        if type(close_date) == str:
            pairs.append((500, close_date, coalesce(close_price, current_price, list_price)))
        pairs.sort(key=lambda x: x[1])
        return pairs

def clean_events(events: list) -> list:
    """Remove out of order events (i.e. all status codes should be in
       ascending order)

    Args:
        events (list): list of events in order of date

    Returns:
        list: list of cleaned events
    """
    index = 1
    while index <= len(events):
        try:
            if events[index] < events[index - 1]:
                del events[index]
            else:
                index += 1
        except IndexError:
            break
    return events

def clean_expiry(events: list, status: str) -> list:
    """Remove expiry event if status is not expired

    Args:
        events (list): list of events
        status (str): status of listing

    Returns:
        list: list of events with expiry event removed if necessary
    """
    if status != 'X':
        t = None
        for i in range(len(events)):
            if 300 in events[i]:
                t = i
        if t:
            events.pop(t)
    return events

def add_withdraw_cancel(events, status, withdraw_date, expiration_date, current_price, list_price, status_change_timestamp) -> list:
    """Add withdraw, cancel, and hold events

    Returns:
        list: list of events with cancel, withdraw, and hold events added
    """
    if type(withdraw_date) == str and status != 640:
        events.append((status, withdraw_date, coalesce(current_price, list_price)))
    elif type(status_change_timestamp) == str:
        events.append((status, status_change_timestamp, coalesce(current_price, list_price)))
    else:
        events.append((status, expiration_date, coalesce(current_price, list_price)))
    return events

def create_listing_history(close_date, expiration_date, listing_contract_date, purchase_contract_date, withdrawn_date,
                           list_price,current_price, original_list_price, close_price, status, status_change_timestamp) -> list:
    """Given the dates and prices available, generate all events

    Returns:
        list: list of ordered and cleaned events that a listing went through
    """
    ec = event_codes[status]
    events = []
    if ec == 50:
        events.append(f'{ec}: {listing_contract_date}, {coalesce(original_list_price, list_price)}')
    else:
        events = create_pairs(close_date, expiration_date, listing_contract_date,
                              purchase_contract_date, list_price,current_price, 
                              original_list_price, close_price)
        if ec in (600, 620, 640):
            events = add_withdraw_cancel(events, ec, withdrawn_date, expiration_date, current_price, list_price, status_change_timestamp)
        events = clean_events(events)
        events = clean_expiry(events, status)
    return events

# %%
events = [create_listing_history(close_date, expiration_date, listing_contract_date, purchase_contract_date, withdrawn_date, 
                        list_price,current_price, original_list_price, close_price, status, status_change_timestamp) for close_date, expiration_date, listing_contract_date, purchase_contract_date, withdrawn_date,
                           list_price,current_price, original_list_price, close_price, status, status_change_timestamp in zip(listings_sample.close_date, listings_sample.expiration_date, listings_sample.listing_contract_date, listings_sample.purchase_contract_date, listings_sample.withdrawn_date,
                           listings_sample.list_price,listings_sample.current_price, listings_sample.original_list_price, listings_sample.close_price, listings_sample.status, listings_sample.status_change_timestamp)]
len(events)
# Out:
# 337904

# %%
listing_keys = list(set(history_sample['resource_record_key']))
history_sample[history_sample['resource_record_key'] == listing_keys[3]]
# Out:
#        new_value               field_name  history_key modification_timestamp  \
# 253827         P           STANDARDSTATUS      9767882    2020-01-13 17:20:18
# 380618     2.500  BUYERAGENCYCOMPENSATION      9651862    2020-01-01 14:46:03
# 382506         A           STANDARDSTATUS      9650143    2020-01-01 14:46:03
#
#         resource_record_key
# 253827            363855877
# 380618            363855877
# 382506            363855877

# %%
listings_sample['events'] = events

# %%
listings_sample.head()
# Out:
#    source_id  close_date expiration_date listing_contract_date  \
# 0   10002014  2015-10-27      2016-04-28            2015-06-24
# 1  100198211  2017-05-07      2017-06-30            2017-03-01
# 2   10025396         NaN      2020-06-30            2015-06-28
# 3   10025573         NaN      2020-06-30            2015-06-28
# 4   10051516  2016-02-23      2016-02-29            2015-07-04
#
#   purchase_contract_date withdrawn_date  list_price  current_price  \
# 0             2015-07-17            NaN    219900.0       220000.0
# 1             2017-04-27            NaN      2350.0         2350.0
# 2                    NaN     2020-02-24   8750000.0      8750000.0
# 3                    NaN     2020-02-24   5300000.0      5300000.0
# 4             2016-01-08            NaN    245000.0       240000.0
#
#    original_list_price  close_price price_change_timestamp status  \
# 0             219900.0     220000.0                    NaN      S
# 1               2350.0       2350.0    2017-03-22 20:27:45      S
# 2           12500000.0          NaN    2017-12-02 10:46:26      X
# 3            6200000.0          NaN    2017-12-02 10:52:23      X
# 4             265000.0     240000.0    2015-08-19 18:49:13      S
#
#    previous_list_price previous_status status_change_timestamp on_market_date  \
# 0                  NaN               P     2015-10-27 17:23:41     2015-06-24
# 1                  NaN               U     2017-05-07 19:48:00     2017-03-01
# 2           12500000.0               W     2020-07-01 00:04:17     2015-06-28
# 3            6200000.0               W     2020-07-01 01:04:19     2015-06-28
# 4             249900.0               U     2016-02-25 14:40:27     2015-07-04
#
#   off_market_date contingent_date original_entry_timestamp  \
# 0      2015-07-17             NaN      2015-06-24 07:56:16
# 1      2017-05-07             NaN      2017-03-22 20:27:45
# 2      2020-02-24             NaN      2015-06-28 11:00:14
# 3      2020-02-24             NaN      2015-06-28 12:10:16
# 4      2016-02-23             NaN      2015-07-04 20:25:01
#
#                                               events
# 0  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...

# %% [markdown]
# ## Creating Events from HISTORY Object

# %%
def get_og_event(listing_key: int) -> list:
    """Get original event of listing

    Args:
        listing_key (int): key of listing

    Returns:
        list: first event of listing history
    """
    try:
        listing = listings_sample[listings_sample['source_id'] == listing_key]
        list_date = listing['original_entry_timestamp'].values[0]
        list_price = coalesce(listing['original_list_price'].values[0], listing['list_price'].values[0])
        return [100, list_date, list_price]
    except IndexError:
        return [100, None, None]

def add_event(history_row: pd.Series, lh: dict):
    """Given a change record, create a new event for that listing and add
    it to the listing's history.

    Args:
        history_row (pd.Series): row of change history
        lh (dict): dictionary of listing histories with key as listing_key
    """
    try:
        last_event = lh[history_row['resource_record_key']][-1]
    except KeyError:
        last_event = get_og_event(history_row['resource_record_key'])
        lh[history_row['resource_record_key']] = [last_event]
        #last_event = (100, 0, 0)
    new_time = history_row['modification_timestamp']
    if 'STATUS' in history_row['field_name']:
        try:
            new_status = event_codes[history_row['new_value']]
        except KeyError:
            print(f"{history_row['new_value']} not found")
            return None
        if new_status == last_event[0]:
            if new_status == 100:
                for i in range(len(lh[history_row['resource_record_key']])):
                    lh[history_row['resource_record_key']][i][0] = 50
                last_event = lh[history_row['resource_record_key']][-1]
            elif new_status == 500:
                return None
        current_event = [new_status, new_time, last_event[2]]
        lh[history_row['resource_record_key']].append(current_event)
    elif 'LISTPRICE' == history_row['field_name']:
        current_event = [last_event[0], new_time, history_row['new_value']]
        lh[history_row['resource_record_key']].append(current_event)
    else:
        if last_event[0] == 500:
            last_event[-1] = history_row['new_value']
            lh[history_row['resource_record_key']][-1] = last_event
        else:
            current_event = [500, new_time, history_row['new_value']]
            lh[history_row['resource_record_key']].append(current_event)

def clean_coming_soon(lh: list) -> list:
    if lh[-1][0] == 50:
        lh = [lh[-1]]
    return lh

# %%
history_sample.groupby('resource_record_key')['history_key'].nunique().sort_values(ascending=False)#.to_clipboard()
# Out:
# resource_record_key
# 365507734    79
# 365807302    38
# 367465241    33
# 363654223    28
# 13401009     27
#              ..
# 360135615     1
# 360135650     1
# 360135942     1
# 360135954     1
# 362925237     1
# Name: history_key, Length: 376457, dtype: int64

# %%
listings_sample[listings_sample['source_id'] == 1061779]
# Out:
#     source_id  close_date expiration_date listing_contract_date  \
# 20    1061779  2013-02-22      2013-06-07            2012-12-06
#
#    purchase_contract_date withdrawn_date  list_price  current_price  \
# 20             2012-12-18            NaN    215000.0       217000.0
#
#     original_list_price  close_price price_change_timestamp status  \
# 20             215000.0     217000.0                    NaN      S
#
#     previous_list_price previous_status status_change_timestamp  \
# 20                  NaN               P     2013-02-22 08:38:47
#
#    on_market_date off_market_date contingent_date original_entry_timestamp  \
# 20     2012-12-18      2012-12-18             NaN      2012-12-06 21:26:10
#
#                                                events
# 20  [(100, 2012-12-06, 215000.0), (240, 2012-12-18...

# %%
history_sample[history_sample['resource_record_key'] == 1061779]
# Out:
#       new_value                 field_name  history_key  \
# 5923     217000               SELLINGPRICE      9994575
# 5924        2.5  SELLINGOFFICECOMPENSATION      9994574
# 9399          S                     STATUS      9991390
# 9401          P                     STATUS      9991389
# 9402          B                     STATUS      9991388
# 9403          A                     STATUS      9991387
# 9404          P                     STATUS      9991386
# 9405          A                     STATUS      9991385
# 11467    215000                  LISTPRICE      9989505
#
#       modification_timestamp  resource_record_key
# 5923     2020-01-31 16:55:00              1061779
# 5924     2020-01-31 16:55:00              1061779
# 9399     2020-01-31 16:55:00              1061779
# 9401     2020-01-31 16:55:00              1061779
# 9402     2020-01-31 16:55:00              1061779
# 9403     2020-01-31 16:55:00              1061779
# 9404     2020-01-31 16:55:00              1061779
# 9405     2020-01-31 16:55:00              1061779
# 11467    2020-01-31 16:55:00              1061779

# %%
history_sample = history_sample[(history_sample['field_name'].str.contains('STATUS')) | (history_sample['field_name'].str.contains('PRICE'))]
history_sample.sort_values(['modification_timestamp', 'history_key'], inplace=True)
listing_history = {}
for index, row in tqdm(history_sample.iterrows(), total=len(history_sample)):
    add_event(row, listing_history)
for k in listing_history:
    listing_history[k] = clean_coming_soon(listing_history[k])
# Out:
#   0%|          | 0/807781 [00:00<?, ?it/s]

# %%
s = pd.DataFrame(columns=['listing_key', 'listing_history'])
l = []
lh = []
for k in listing_history:
    l.append(k)
    lh.append(listing_history[k])
s['listing_key'] = l
s['listing_history'] = lh
s.head()
# Out:
#    listing_key                                    listing_history
# 0    359956806  [[50, 2018-09-04 10:14:32, 464900.0], [100, 20...
# 1    359954635  [[50, 2018-09-03 12:22:01, 669000.0], [100, 20...
# 2    359948951  [[50, 2018-08-31 21:14:01, 380000.0], [100, 20...
# 3    359946798  [[50, 2018-08-31 15:51:31, 664900.0], [100, 20...
# 4    359944373  [[50, 2018-08-31 11:41:00, 850000.0], [100, 20...

# %%
listings_sample.merge(right=s, how='left', right_on='listing_key', left_on='source_id')[['source_id', 'events', 'listing_history']].to_csv('data/listings_sample_with_events_and_lh.csv', index=False)

# %% [markdown]
# ## Checking out the output

# %%
history_sample[history_sample['resource_record_key'] == 13401009]
# Out:
#       new_value      field_name  history_key modification_timestamp  \
# 13934    354900       LISTPRICE       998725    2019-04-11 11:35:02
# 13913         A          STATUS       998727    2019-04-11 11:35:02
# 13835         B          STATUS       998734    2019-04-11 11:35:02
# 13736         P          STATUS       998743    2019-04-11 11:35:02
# 13685         A          STATUS       998748    2019-04-11 11:35:02
# 13640    359900       LISTPRICE       998752    2019-04-11 11:35:02
# 13630    354900       LISTPRICE       998753    2019-04-11 11:35:02
# 13552         P          STATUS       998760    2019-04-11 11:35:02
# 13434         B          STATUS       998771    2019-04-11 11:35:02
# 13424         A          STATUS       998772    2019-04-11 11:35:02
# 13413         H          STATUS       998773    2019-04-11 11:35:02
# 13402         P          STATUS       998774    2019-04-11 11:35:02
# 13391         A          STATUS       998775    2019-04-11 11:35:02
# 13337         W          STATUS       998780    2019-04-11 11:35:02
# 13184    366000       LISTPRICE       998794    2019-04-11 11:35:02
# 13173         A  STANDARDSTATUS       998795    2019-04-11 11:35:02
# 12964    355000       LISTPRICE       998814    2019-04-11 11:35:02
# 12812         P  STANDARDSTATUS       998828    2019-04-11 11:35:02
# 12801         A  STANDARDSTATUS       998829    2019-04-11 11:35:02
# 12778    350000       LISTPRICE       998831    2019-04-11 11:35:02
# 12767    348900       LISTPRICE       998832    2019-04-11 11:35:02
# 12756    344900       LISTPRICE       998833    2019-04-11 11:35:02
# 12723         U  STANDARDSTATUS       998836    2019-04-11 11:35:02
# 12668         P  STANDARDSTATUS       998841    2019-04-11 11:35:02
# 12646         S  STANDARDSTATUS       998843    2019-04-11 11:35:02
# 12635    345000      CLOSEPRICE       998844    2019-04-11 11:35:02
#
#        resource_record_key
# 13934             13401009
# 13913             13401009
# 13835             13401009
# 13736             13401009
# 13685             13401009
# 13640             13401009
# 13630             13401009
# 13552             13401009
# 13434             13401009
# 13424             13401009
# 13413             13401009
# 13402             13401009
# 13391             13401009
# 13337             13401009
# 13184             13401009
# 13173             13401009
# 12964             13401009
# 12812             13401009
# 12801             13401009
# 12778             13401009
# 12767             13401009
# 12756             13401009
# 12723             13401009
# 12668             13401009
# 12646             13401009
# 12635             13401009

# %%
listing_history[13401009]
# Out:
# [[50, '2016-05-25 10:57:49', 354900.0],
#  [50, '2019-04-11 11:35:02', '354900'],
#  [100, '2019-04-11 11:35:02', '354900'],
#  [200, '2019-04-11 11:35:02', '354900'],
#  [240, '2019-04-11 11:35:02', '354900'],
#  [100, '2019-04-11 11:35:02', '354900'],
#  [100, '2019-04-11 11:35:02', '359900'],
#  [100, '2019-04-11 11:35:02', '354900'],
#  [240, '2019-04-11 11:35:02', '354900'],
#  [200, '2019-04-11 11:35:02', '354900'],
#  [100, '2019-04-11 11:35:02', '354900'],
#  [640, '2019-04-11 11:35:02', '354900'],
#  [240, '2019-04-11 11:35:02', '354900'],
#  [100, '2019-04-11 11:35:02', '354900'],
#  [600, '2019-04-11 11:35:02', '354900'],
#  [600, '2019-04-11 11:35:02', '366000'],
#  [100, '2019-04-11 11:35:02', '366000'],
#  [100, '2019-04-11 11:35:02', '355000'],
#  [240, '2019-04-11 11:35:02', '355000'],
#  [100, '2019-04-11 11:35:02', '355000'],
#  [100, '2019-04-11 11:35:02', '350000'],
#  [100, '2019-04-11 11:35:02', '348900'],
#  [100, '2019-04-11 11:35:02', '344900'],
#  [240, '2019-04-11 11:35:02', '344900'],
#  [240, '2019-04-11 11:35:02', '344900'],
#  [500, '2019-04-11 11:35:02', '345000']]

# %%
listings_sample[listings_sample['source_id'] == 13401009]
# Out:
#     source_id  close_date expiration_date listing_contract_date  \
# 82   13401009  2016-12-29      2017-03-31            2016-05-25
#
#    purchase_contract_date withdrawn_date  list_price  current_price  \
# 82             2016-11-20            NaN    344900.0       345000.0
#
#     original_list_price  close_price price_change_timestamp status  \
# 82             354900.0     345000.0    2016-11-22 10:33:35      S
#
#     previous_list_price previous_status status_change_timestamp  \
# 82             348900.0               P     2016-12-30 15:11:47
#
#    on_market_date off_market_date contingent_date original_entry_timestamp  \
# 82     2016-09-30      2016-11-20             NaN      2016-05-25 10:57:49
#
#                                                events
# 82  [(100, 2016-05-25, 354900.0), (240, 2016-11-20...

# %%
history_sample[history_sample['resource_record_key'] == 360135615]
# Out:
#        new_value      field_name  history_key modification_timestamp  \
# 391642         K  STANDARDSTATUS        96414    2019-01-11 11:15:42
#
#         resource_record_key
# 391642            360135615

# %%
listing_history[360135615]
# Out:
# [[100, '2018-09-29 11:53:42', 135000.0],
#  [620, '2019-01-11 11:15:42', 135000.0]]

# %%
listings_sample[listings_sample['source_id'] == 360135615]
# Out:
#      source_id close_date expiration_date listing_contract_date  \
# 676  360135615        NaN      2019-02-28            2018-09-29
#
#     purchase_contract_date withdrawn_date  list_price  current_price  \
# 676                    NaN            NaN    125000.0       125000.0
#
#      original_list_price  close_price price_change_timestamp status  \
# 676             135000.0          NaN    2018-11-06 18:43:35      K
#
#      previous_list_price previous_status status_change_timestamp  \
# 676             135000.0               A     2019-01-11 11:15:42
#
#     on_market_date off_market_date contingent_date original_entry_timestamp  \
# 676     2018-09-29      2019-01-11             NaN      2018-09-29 11:53:42
#
#                                                 events
# 676  [(100, 2018-09-29, 135000.0), (620, 2019-01-11...

# %%
history_sample[history_sample['resource_record_key'] == 350951796]
# Out:
#        new_value      field_name  history_key modification_timestamp  \
# 225985         A  STANDARDSTATUS      9793306    2020-01-18 00:01:44
# 329911         H  STANDARDSTATUS      9698422    2020-01-19 10:07:36
# 305151         A  STANDARDSTATUS      9721005    2020-01-20 00:02:18
# 45533          H  STANDARDSTATUS      9958338    2020-01-27 12:49:25
#
#         resource_record_key
# 225985            350951796
# 329911            350951796
# 305151            350951796
# 45533             350951796

# %%
listing_history[350951796]
# Out:
# [[50, '2018-05-29 14:32:11', 435000.0],
#  [100, '2020-01-18 00:01:44', 435000.0],
#  [640, '2020-01-19 10:07:36', 435000.0],
#  [100, '2020-01-20 00:02:18', 435000.0],
#  [640, '2020-01-27 12:49:25', 435000.0]]

# %%
listings_sample[listings_sample['source_id'] == 350951796]['status']
# Out:
# 294    K
# Name: status, dtype: object

# %%
listings_sample[listings_sample['status'] == 'K']['events'].head(10)
# Out:
# 6     [(100, 2015-08-01, 739888.0), (620, 2016-02-16...
# 8     [(100, 2015-08-12, 85000.0), (620, 2016-03-02 ...
# 17    [(100, 2015-09-25, 325000.0), (620, 2015-12-18...
# 24    [(100, 2015-10-21, 1200.0), (620, 2016-01-05 1...
# 26    [(100, 2015-10-24, 299900.0), (620, 2015-12-19...
# 34    [(100, 2015-12-21, 749900.0), (620, 2016-02-19...
# 38    [(100, 2016-01-09, 3338000.0), (620, 2020-02-2...
# 59    [(100, 2017-05-01, 19900.0), (240, 2019-06-11,...
# 74    [(100, 2017-05-30, 3290000.0), (620, 2019-11-0...
# 75    [(100, 2017-05-31, 468500.0), (240, 2018-05-08...
# Name: events, dtype: object

# %%
history_sample[history_sample['resource_record_key'] == 10390789]
# Out:
#       new_value    field_name  history_key modification_timestamp  \
# 14741    399900     LISTPRICE       998651    2019-04-11 11:35:02
# 14720         A        STATUS       998653    2019-04-11 11:35:02
# 14709         P        STATUS       998654    2019-04-11 11:35:02
# 14261    399900  SELLINGPRICE       998695    2019-04-11 11:35:02
# 14250         S        STATUS       998696    2019-04-11 11:35:02
#
#        resource_record_key
# 14741             10390789
# 14720             10390789
# 14709             10390789
# 14261             10390789
# 14250             10390789

# %%
listing_history[10390789]
# Out:
# [[50, '2015-09-07 11:32:22', 399900.0],
#  [50, '2019-04-11 11:35:02', '399900'],
#  [100, '2019-04-11 11:35:02', '399900'],
#  [240, '2019-04-11 11:35:02', '399900'],
#  [500, '2019-04-11 11:35:02', '399900']]

# %%
events_sample = listings_sample.merge(right=s, how='left', right_on='listing_key', left_on='source_id')[['source_id', 'events', 'listing_history', 'status']]
events_sample.head()
# Out:
#    source_id                                             events  \
# 0   10002014  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1  100198211  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2   10025396  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3   10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4   10051516  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...
#
#                                      listing_history status
# 0  [[50, 2015-06-24 07:56:16, 219900.0], [50, 201...      S
# 1  [[50, 2017-03-22 20:27:45, 2350.0], [100, 2019...      S
# 2  [[100, 2015-06-28 11:00:14, 12500000.0], [600,...      X
# 3  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X
# 4  [[50, 2015-07-04 20:25:01, 265000.0], [50, 201...      S

# %%
for status in set(events_sample['status']):
    events_sample[events_sample['status'] == status].to_csv(f'data/events_comparison_{status}.csv')

# %%
listings_sample.merge(right=s, how='left', right_on='listing_key', left_on='source_id').head()
# Out:
#    source_id  close_date expiration_date listing_contract_date  \
# 0   10002014  2015-10-27      2016-04-28            2015-06-24
# 1  100198211  2017-05-07      2017-06-30            2017-03-01
# 2   10025396         NaN      2020-06-30            2015-06-28
# 3   10025573         NaN      2020-06-30            2015-06-28
# 4   10051516  2016-02-23      2016-02-29            2015-07-04
#
#   purchase_contract_date withdrawn_date  list_price  current_price  \
# 0             2015-07-17            NaN    219900.0       220000.0
# 1             2017-04-27            NaN      2350.0         2350.0
# 2                    NaN     2020-02-24   8750000.0      8750000.0
# 3                    NaN     2020-02-24   5300000.0      5300000.0
# 4             2016-01-08            NaN    245000.0       240000.0
#
#    original_list_price  close_price  ... previous_list_price previous_status  \
# 0             219900.0     220000.0  ...                 NaN               P
# 1               2350.0       2350.0  ...                 NaN               U
# 2           12500000.0          NaN  ...          12500000.0               W
# 3            6200000.0          NaN  ...           6200000.0               W
# 4             265000.0     240000.0  ...            249900.0               U
#
#    status_change_timestamp on_market_date off_market_date contingent_date  \
# 0      2015-10-27 17:23:41     2015-06-24      2015-07-17             NaN
# 1      2017-05-07 19:48:00     2017-03-01      2017-05-07             NaN
# 2      2020-07-01 00:04:17     2015-06-28      2020-02-24             NaN
# 3      2020-07-01 01:04:19     2015-06-28      2020-02-24             NaN
# 4      2016-02-25 14:40:27     2015-07-04      2016-02-23             NaN
#
#   original_entry_timestamp                                             events  \
# 0      2015-06-24 07:56:16  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1      2017-03-22 20:27:45  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2      2015-06-28 11:00:14  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3      2015-06-28 12:10:16  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4      2015-07-04 20:25:01  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...
#
#    listing_key                                    listing_history
# 0   10002014.0  [[50, 2015-06-24 07:56:16, 219900.0], [50, 201...
# 1  100198211.0  [[50, 2017-03-22 20:27:45, 2350.0], [100, 2019...
# 2   10025396.0  [[100, 2015-06-28 11:00:14, 12500000.0], [600,...
# 3   10025573.0  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...
# 4   10051516.0  [[50, 2015-07-04 20:25:01, 265000.0], [50, 201...
#
# [5 rows x 22 columns]

# %%
events_sample[events_sample['source_id'] == 10025573]
# Out:
#    source_id                                             events  \
# 3   10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
#
#                                      listing_history status
# 3  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X

# %%
listing_history[362150008]
# Out:
# [[100, '2019-02-19 11:38:38', 950000.0],
#  [300, '2020-01-01 06:33:00', 950000.0],
#  [300, '2020-01-15 11:53:37', '985000.00'],
#  [100, '2020-01-15 11:53:37', '985000.00']]

# %%
history_sample[history_sample['resource_record_key'] == 362150008]
# Out:
#         new_value      field_name  history_key modification_timestamp  \
# 366501          X  STANDARDSTATUS      9664926    2020-01-01 06:33:00
# 346627  985000.00       LISTPRICE      9683162    2020-01-15 11:53:37
# 346535          A  STANDARDSTATUS      9683246    2020-01-15 11:53:37
#
#         resource_record_key
# 366501            362150008
# 346627            362150008
# 346535            362150008

# %%
events_sample.head()
# Out:
#    source_id                                             events  \
# 0   10002014  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1  100198211  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2   10025396  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3   10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4   10051516  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...
#
#                                      listing_history status
# 0  [[50, 2015-06-24 07:56:16, 219900.0], [50, 201...      S
# 1  [[50, 2017-03-22 20:27:45, 2350.0], [100, 2019...      S
# 2  [[100, 2015-06-28 11:00:14, 12500000.0], [600,...      X
# 3  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X
# 4  [[50, 2015-07-04 20:25:01, 265000.0], [50, 201...      S

# %%
def events_time_diff(lh: list) -> list:
    """get average time in between events

    Args:
        lh (list): list of events

    Returns:
        datetime.timedelta: average difference in time between events
    """
    timediff = []
    for i in range(len(lh)-1):
        try:
            e1 = datetime.fromisoformat(lh[i][1])
            e2 = datetime.fromisoformat(lh[i+1][1])
            timediff.append(e2 - e1)
        except TypeError:
            print(lh[i], lh[i+1])
            pass
    '''if len(timediff) > 0:
        return sum(timediff, timedelta(0)) / len(timediff)
    else:
        return None'''
    return timediff

# %%
events_diff = pd.DataFrame({'source_id': [x for x, y in zip(events_sample['source_id'], events_sample['listing_history']) if type(y) == list], 'avg_timediff': [events_time_diff(x) for x in events_sample.listing_history if type(x) == list]})
# Out:
# [50, nan, 775000.0] [100, '2019-04-04 09:23:11', 775000.0]
# [100, nan, 439000.0] [500, '2021-11-19 06:20:24', '439000']
# [100, nan, 295000.0] [500, '2021-11-06 20:16:46', '285000']

# %%
events_diff.head()
# Out:
#    source_id                                       avg_timediff
# 0   10002014  [1297 days, 6:03:45, 0:00:00, 0:00:00, 0:00:00...
# 1  100198211  [749 days, 18:37:17, 0:00:00, 0:00:00, 0:00:00...
# 2   10025396                              [1701 days, 22:45:47]
# 3   10025573                              [1701 days, 21:35:13]
# 4   10051516  [1376 days, 15:10:01, 0:00:00, 0:00:00, 0:00:0...

# %%
events_diff['has_zero'] = [1 if timedelta(0) in x else 0 for x in events_diff.avg_timediff]
events_diff[events_diff['has_zero'] == 1]
# Out:
#         source_id                                       avg_timediff  has_zero
# 0        10002014  [1297 days, 6:03:45, 0:00:00, 0:00:00, 0:00:00...         1
# 1       100198211  [749 days, 18:37:17, 0:00:00, 0:00:00, 0:00:00...         1
# 4        10051516  [1376 days, 15:10:01, 0:00:00, 0:00:00, 0:00:0...         1
# 5        10089929  [1370 days, 14:45:45, 0:00:00, 0:00:00, 0:00:0...         1
# 6        10203662  [1259 days, 5:26:17, 0:00:00, 0:00:00, 0:00:00...         1
# ...           ...                                                ...       ...
# 336971  367461486                                          [0:00:00]         1
# 336972  367461544                                          [0:00:00]         1
# 336973  367461621                                          [0:00:00]         1
# 336974  367461723                                          [0:00:00]         1
# 336977  367464545                                          [0:00:00]         1
#
# [150355 rows x 3 columns]

# %%
len(events_diff[events_diff['has_zero'] == 1])/len(events_diff)
# Out:
# 0.44618110166121633

# %%
events_diff.to_csv('data/avg_time_difference.csv', index=False)

# %%
events_sample.head()
# Out:
#    source_id                                             events  \
# 0   10002014  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1  100198211  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2   10025396  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3   10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4   10051516  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...
#
#                                      listing_history status
# 0  [[50, 2015-06-24 07:56:16, 219900.0], [50, 201...      S
# 1  [[50, 2017-03-22 20:27:45, 2350.0], [100, 2019...      S
# 2  [[100, 2015-06-28 11:00:14, 12500000.0], [600,...      X
# 3  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X
# 4  [[50, 2015-07-04 20:25:01, 265000.0], [50, 201...      S

# %%
correct_end = 0
incorrect_end = 0
correct = []
incorrect = []
for index, row in events_sample.iterrows():
    # print(row)
    if type(row['listing_history']) == list:
        if row['listing_history'][-1][0] == event_codes[row['status']]:
            correct_end += 1
            correct.append(index)
        else:
            incorrect_end += 1
            incorrect.append(index)

print(correct_end, incorrect_end)
# Out:
# 170326 166656

# %%
events_sample[events_sample.index.isin(incorrect)]
# Out:
#         source_id                                             events  \
# 2        10025396  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3        10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 6        10203662  [(100, 2015-08-01, 739888.0), (620, 2016-02-16...
# 8        10265990  [(100, 2015-08-12, 85000.0), (620, 2016-03-02 ...
# 15       10419458  [(100, 2015-09-11, 550000.0), (240, 2020-12-07...
# ...           ...                                                ...
# 337898  367462126  [(100, 2021-10-21, 1700000.0), (620, 2022-04-1...
# 337899  367464545  [(100, 2021-10-22, 269000.0), (600, 2023-06-07...
# 337900    4119647  [(100, 2009-04-01, 160000.0), (300, 2010-01-04...
# 337901   79771482  [(100, 2017-02-12, 40000.0), (300, 2022-01-19,...
# 337902    8060235  [(100, 1995-04-18, 450000.0), (240, 1996-05-09...
#
#                                           listing_history status
# 2       [[100, 2015-06-28 11:00:14, 12500000.0], [600,...      X
# 3       [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X
# 6       [[50, 2015-08-01 08:33:44, 739888.0], [50, 201...      K
# 8       [[50, 2015-08-12 21:34:40, 85000.0], [50, 2019...      K
# 15      [[100, 2015-09-11 19:24:23, 550000.0], [100, 2...      S
# ...                                                   ...    ...
# 337898  [[50, 2021-10-21 09:24:19, 1700000.0], [100, 2...      K
# 337899  [[50, 2021-10-22 13:00:59, 269000.0], [100, 20...      W
# 337900  [[100, 2009-04-01 22:00:00, 160000.0], [500, 2...      X
# 337901  [[100, 2017-02-12 16:32:59, 40000.0], [100, 20...      X
# 337902  [[50, 2014-10-17 13:09:32, 450000.0], [100, 20...      S
#
# [166656 rows x 4 columns]

# %%
history_sample[history_sample['resource_record_key'] == 10025396]
# Out:
#      new_value      field_name  history_key modification_timestamp  \
# 2137         W  STANDARDSTATUS      9998040    2020-02-24 09:46:01
#
#       resource_record_key
# 2137             10025396

# %%
events_sample.listing_history[0][-1][0]
# Out:
# 500

# %%
events_sample.status[0]
# Out:
# 'S'

# %%
correct_end = 0
incorrect_end = 0
for index, row in events_sample.iterrows():
    # print(row)
    if type(row['listing_history']) == list:
        for event in row['listing_history']:
            if 500 in event:
                for e in row['listing_history']:    
                    if 240 in e:
                        correct_end += 1
                        break
                else:
                    incorrect_end += 1

print(correct_end, incorrect_end)
# Out:
# 45440 68492

# %%
events_sample.head()
# Out:
#    source_id                                             events  \
# 0   10002014  [(100, 2015-06-24, 219900.0), (240, 2015-07-17...
# 1  100198211  [(100, 2017-03-01, 2350.0), (240, 2017-04-27, ...
# 2   10025396  [(100, 2015-06-28, 12500000.0), (300, 2020-06-...
# 3   10025573  [(100, 2015-06-28, 6200000.0), (300, 2020-06-3...
# 4   10051516  [(100, 2015-07-04, 265000.0), (240, 2016-01-08...
#
#                                      listing_history status
# 0  [[50, 2015-06-24 07:56:16, 219900.0], [50, 201...      S
# 1  [[50, 2017-03-22 20:27:45, 2350.0], [100, 2019...      S
# 2  [[100, 2015-06-28 11:00:14, 12500000.0], [600,...      X
# 3  [[100, 2015-06-28 12:10:16, 6200000.0], [600, ...      X
# 4  [[50, 2015-07-04 20:25:01, 265000.0], [50, 201...      S

# %%
events_sample['listing_history'][0]
# Out:
# [[50, '2015-06-24 07:56:16', 219900.0],
#  [50, '2019-01-11 14:00:01', '219900'],
#  [100, '2019-01-11 14:00:01', '219900'],
#  [200, '2019-01-11 14:00:01', '219900'],
#  [240, '2019-01-11 14:00:01', '219900'],
#  [500, '2019-01-11 14:00:01', '220000']]

# %%
correct_end = 0
incorrect_end = 0
correct = []
incorrect = []
for index, row in events_diff.iterrows():
    try:
        if row['avg_timediff'][0] < timedelta(days=365):
            correct_end += 1
            correct.append(index)
        else:
            incorrect_end += 1
            incorrect.append(index)
    except:
        print(row)
print(correct_end, incorrect_end)
# Out:
# source_id       367383247
# avg_timediff           []
# has_zero                0
# Name: 171386, dtype: object
# source_id       367388621
# avg_timediff           []
# has_zero                0
# Name: 171407, dtype: object
# source_id       367708902
# avg_timediff           []
# has_zero                0
# Name: 174581, dtype: object
# source_id       367708906
# avg_timediff           []
# has_zero                0
# Name: 174585, dtype: object
# source_id       367708992
# avg_timediff           []
# has_zero                0
# Name: 174613, dtype: object
# source_id       367709165
# avg_timediff           []
# has_zero                0
# Name: 174655, dtype: object
# source_id       367709349
# avg_timediff           []
# has_zero                0
# Name: 174701, dtype: object
# source_id       367709696
# avg_timediff           []
# has_zero                0
# Name: 174782, dtype: object
# source_id       367709708
# avg_timediff           []
# has_zero                0
# Name: 174791, dtype: object
# source_id       367709779
# avg_timediff           []
# has_zero                0
# Name: 174808, dtype: object
# source_id       367709968
# avg_timediff           []
# has_zero                0
# Name: 174856, dtype: object
# source_id       367710109
# avg_timediff           []
# has_zero                0
# Name: 174886, dtype: object
# source_id       367710279
# avg_timediff           []
# has_zero                0
# Name: 174940, dtype: object
# source_id       367710513
# avg_timediff           []
# has_zero                0
# Name: 175007, dtype: object
# source_id       367712483
# avg_timediff           []
# has_zero                0
# Name: 175440, dtype: object
# source_id       367738407
# avg_timediff           []
# has_zero                0
# Name: 175886, dtype: object
# source_id       367740315
# avg_timediff           []
# has_zero                0
# Name: 175920, dtype: object
# source_id       367740533
# avg_timediff           []
# has_zero                0
# Name: 175936, dtype: object
# source_id       367740562
# avg_timediff           []
# has_zero                0
# Name: 175937, dtype: object
# source_id       367740989
# avg_timediff           []
# has_zero                0
# Name: 176029, dtype: object
# source_id       367741437
# avg_timediff           []
# has_zero                0
# Name: 176110, dtype: object
# source_id       367741455
# avg_timediff           []
# has_zero                0
# Name: 176121, dtype: object
# source_id       367741541
# avg_timediff           []
# has_zero                0
# Name: 176146, dtype: object
# source_id       367741550
# avg_timediff           []
# has_zero                0
# Name: 176148, dtype: object
# source_id       367741602
# avg_timediff           []
# has_zero                0
# Name: 176161, dtype: object
# source_id       367741874
# avg_timediff           []
# has_zero                0
# Name: 176225, dtype: object
# source_id       367741899
# avg_timediff           []
# has_zero                0
# Name: 176227, dtype: object
# source_id       367741970
# avg_timediff           []
# has_zero                0
# Name: 176250, dtype: object
# source_id       367742185
# avg_timediff           []
# has_zero                0
# Name: 176329, dtype: object
# source_id       367742229
# avg_timediff           []
# has_zero                0
# Name: 176355, dtype: object
# source_id       367742542
# avg_timediff           []
# has_zero                0
# Name: 176436, dtype: object
# source_id       367742963
# avg_timediff           []
# has_zero                0
# Name: 176545, dtype: object
# source_id       367743329
# avg_timediff           []
# has_zero                0
# Name: 176649, dtype: object
# source_id       367745200
# avg_timediff           []
# has_zero                0
# Name: 177088, dtype: object
# source_id       367745371
# avg_timediff           []
# has_zero                0
# Name: 177142, dtype: object
# source_id       367745812
# avg_timediff           []
# has_zero                0
# Name: 177278, dtype: object
# source_id       367746341
# avg_timediff           []
# has_zero                0
# Name: 177445, dtype: object
# source_id       367749811
# avg_timediff           []
# has_zero                0
# Name: 177494, dtype: object
# source_id       367750279
# avg_timediff           []
# has_zero                0
# Name: 177497, dtype: object
# source_id       367752172
# avg_timediff           []
# has_zero                0
# Name: 177518, dtype: object
# source_id       367753328
# avg_timediff           []
# has_zero                0
# Name: 177535, dtype: object
# source_id       367759898
# avg_timediff           []
# has_zero                0
# Name: 177607, dtype: object
# source_id       367760274
# avg_timediff           []
# has_zero                0
# Name: 177708, dtype: object
# source_id       367760514
# avg_timediff           []
# has_zero                0
# Name: 177816, dtype: object
# source_id       367760750
# avg_timediff           []
# has_zero                0
# Name: 178009, dtype: object
# source_id       367760866
# avg_timediff           []
# has_zero                0
# Name: 178115, dtype: object
# source_id       367760871
# avg_timediff           []
# has_zero                0
# Name: 178116, dtype: object
# source_id       367760881
# avg_timediff           []
# has_zero                0
# Name: 178120, dtype: object
# source_id       367760905
# avg_timediff           []
# has_zero                0
# Name: 178143, dtype: object
# source_id       367760906
# avg_timediff           []
# has_zero                0
# Name: 178144, dtype: object
# source_id       367761232
# avg_timediff           []
# has_zero                0
# Name: 178434, dtype: object
# source_id       367761233
# avg_timediff           []
# has_zero                0
# Name: 178435, dtype: object
# source_id       367761243
# avg_timediff           []
# has_zero                0
# Name: 178437, dtype: object
# source_id       367761342
# avg_timediff           []
# has_zero                0
# Name: 178535, dtype: object
# source_id       367761343
# avg_timediff           []
# has_zero                0
# Name: 178536, dtype: object
# source_id       367761353
# avg_timediff           []
# has_zero                0
# Name: 178546, dtype: object
# source_id       367761363
# avg_timediff           []
# has_zero                0
# Name: 178556, dtype: object
# source_id       367761368
# avg_timediff           []
# has_zero                0
# Name: 178561, dtype: object
# source_id       367761370
# avg_timediff           []
# has_zero                0
# Name: 178563, dtype: object
# source_id       367761371
# avg_timediff           []
# has_zero                0
# Name: 178564, dtype: object
# source_id       367761476
# avg_timediff           []
# has_zero                0
# Name: 178582, dtype: object
# source_id       367763004
# avg_timediff           []
# has_zero                0
# Name: 179373, dtype: object
# source_id       367768890
# avg_timediff           []
# has_zero                0
# Name: 179704, dtype: object
# source_id       367769021
# avg_timediff           []
# has_zero                0
# Name: 179723, dtype: object
# source_id       367769724
# avg_timediff           []
# has_zero                0
# Name: 179948, dtype: object
# source_id       367769730
# avg_timediff           []
# has_zero                0
# Name: 179951, dtype: object
# source_id       367769731
# avg_timediff           []
# has_zero                0
# Name: 179952, dtype: object
# source_id       367769732
# avg_timediff           []
# has_zero                0
# Name: 179953, dtype: object
# source_id       367769735
# avg_timediff           []
# has_zero                0
# Name: 179954, dtype: object
# source_id       367769758
# avg_timediff           []
# has_zero                0
# Name: 179960, dtype: object
# source_id       367769896
# avg_timediff           []
# has_zero                0
# Name: 180065, dtype: object
# source_id       367769901
# avg_timediff           []
# has_zero                0
# Name: 180066, dtype: object
# source_id       367770149
# avg_timediff           []
# has_zero                0
# Name: 180279, dtype: object
# source_id       367770282
# avg_timediff           []
# has_zero                0
# Name: 180378, dtype: object
# source_id       367770283
# avg_timediff           []
# has_zero                0
# Name: 180379, dtype: object
# source_id       367770412
# avg_timediff           []
# has_zero                0
# Name: 180486, dtype: object
# source_id       367770531
# avg_timediff           []
# has_zero                0
# Name: 180590, dtype: object
# source_id       367770786
# avg_timediff           []
# has_zero                0
# Name: 180802, dtype: object
# source_id       367770789
# avg_timediff           []
# has_zero                0
# Name: 180803, dtype: object
# source_id       367770916
# avg_timediff           []
# has_zero                0
# Name: 180911, dtype: object
# source_id       367770935
# avg_timediff           []
# has_zero                0
# Name: 180913, dtype: object
# source_id       367771143
# avg_timediff           []
# has_zero                0
# Name: 181007, dtype: object
# source_id       367771144
# avg_timediff           []
# has_zero                0
# Name: 181008, dtype: object
# source_id       367771294
# avg_timediff           []
# has_zero                0
# Name: 181141, dtype: object
# source_id       367771295
# avg_timediff           []
# has_zero                0
# Name: 181142, dtype: object
# source_id       367771427
# avg_timediff           []
# has_zero                0
# Name: 181235, dtype: object
# source_id       367771719
# avg_timediff           []
# has_zero                0
# Name: 181498, dtype: object
# source_id       367771726
# avg_timediff           []
# has_zero                0
# Name: 181499, dtype: object
# source_id       367771749
# avg_timediff           []
# has_zero                0
# Name: 181501, dtype: object
# source_id       367771951
# avg_timediff           []
# has_zero                0
# Name: 181624, dtype: object
# source_id       367771980
# avg_timediff           []
# has_zero                0
# Name: 181625, dtype: object
# source_id       367772408
# avg_timediff           []
# has_zero                0
# Name: 181974, dtype: object
# source_id       367772534
# avg_timediff           []
# has_zero                0
# Name: 182042, dtype: object
# source_id       367772539
# avg_timediff           []
# has_zero                0
# Name: 182047, dtype: object
# source_id       367772541
# avg_timediff           []
# has_zero                0
# Name: 182049, dtype: object
# source_id       367772542
# avg_timediff           []
# has_zero                0
# Name: 182050, dtype: object
# source_id       367774013
# avg_timediff           []
# has_zero                0
# Name: 182799, dtype: object
# source_id       367774129
# avg_timediff           []
# has_zero                0
# Name: 182906, dtype: object
# source_id       367774233
# avg_timediff           []
# has_zero                0
# Name: 182988, dtype: object
# source_id       367774577
# avg_timediff           []
# has_zero                0
# Name: 183138, dtype: object
# source_id       367774858
# avg_timediff           []
# has_zero                0
# Name: 183355, dtype: object
# source_id       367774962
# avg_timediff           []
# has_zero                0
# Name: 183436, dtype: object
# source_id       367774992
# avg_timediff           []
# has_zero                0
# Name: 183458, dtype: object
# source_id       367775091
# avg_timediff           []
# has_zero                0
# Name: 183543, dtype: object
# source_id       367775092
# avg_timediff           []
# has_zero                0
# Name: 183544, dtype: object
# source_id       367775236
# avg_timediff           []
# has_zero                0
# Name: 183650, dtype: object
# source_id       367775237
# avg_timediff           []
# has_zero                0
# Name: 183651, dtype: object
# source_id       367775430
# avg_timediff           []
# has_zero                0
# Name: 183802, dtype: object
# source_id       367775431
# avg_timediff           []
# has_zero                0
# Name: 183803, dtype: object
# source_id       367775521
# avg_timediff           []
# has_zero                0
# Name: 183861, dtype: object
# source_id       367775564
# avg_timediff           []
# has_zero                0
# Name: 183898, dtype: object
# source_id       367775798
# avg_timediff           []
# has_zero                0
# Name: 184039, dtype: object
# source_id       367775811
# avg_timediff           []
# has_zero                0
# Name: 184040, dtype: object
# source_id       367775950
# avg_timediff           []
# has_zero                0
# Name: 184147, dtype: object
# source_id       367776266
# avg_timediff           []
# has_zero                0
# Name: 184289, dtype: object
# source_id       367776269
# avg_timediff           []
# has_zero                0
# Name: 184291, dtype: object
# source_id       367776286
# avg_timediff           []
# has_zero                0
# Name: 184293, dtype: object
# source_id       367776341
# avg_timediff           []
# has_zero                0
# Name: 184323, dtype: object
# source_id       367776461
# avg_timediff           []
# has_zero                0
# Name: 184390, dtype: object
# source_id       367776608
# avg_timediff           []
# has_zero                0
# Name: 184491, dtype: object
# source_id       367776728
# avg_timediff           []
# has_zero                0
# Name: 184594, dtype: object
# source_id       367776730
# avg_timediff           []
# has_zero                0
# Name: 184595, dtype: object
# source_id       367776866
# avg_timediff           []
# has_zero                0
# Name: 184696, dtype: object
# source_id       367777012
# avg_timediff           []
# has_zero                0
# Name: 184801, dtype: object
# source_id       367777027
# avg_timediff           []
# has_zero                0
# Name: 184804, dtype: object
# source_id       367777044
# avg_timediff           []
# has_zero                0
# Name: 184806, dtype: object
# source_id       367777124
# avg_timediff           []
# has_zero                0
# Name: 184879, dtype: object
# source_id       367777160
# avg_timediff           []
# has_zero                0
# Name: 184906, dtype: object
# source_id       367777166
# avg_timediff           []
# has_zero                0
# Name: 184908, dtype: object
# source_id       367777180
# avg_timediff           []
# has_zero                0
# Name: 184910, dtype: object
# source_id       367777181
# avg_timediff           []
# has_zero                0
# Name: 184911, dtype: object
# source_id       367777189
# avg_timediff           []
# has_zero                0
# Name: 184913, dtype: object
# source_id       367777229
# avg_timediff           []
# has_zero                0
# Name: 184953, dtype: object
# source_id       367777298
# avg_timediff           []
# has_zero                0
# Name: 185004, dtype: object
# source_id       367777451
# avg_timediff           []
# has_zero                0
# Name: 185055, dtype: object
# source_id       367777457
# avg_timediff           []
# has_zero                0
# Name: 185056, dtype: object
# source_id       367778279
# avg_timediff           []
# has_zero                0
# Name: 185163, dtype: object
# source_id       367782295
# avg_timediff           []
# has_zero                0
# Name: 185195, dtype: object
# source_id       367782436
# avg_timediff           []
# has_zero                0
# Name: 185317, dtype: object
# source_id       367782437
# avg_timediff           []
# has_zero                0
# Name: 185318, dtype: object
# source_id       367782448
# avg_timediff           []
# has_zero                0
# Name: 185320, dtype: object
# source_id       367782569
# avg_timediff           []
# has_zero                0
# Name: 185408, dtype: object
# source_id       367784656
# avg_timediff           []
# has_zero                0
# Name: 186649, dtype: object
# source_id       367785505
# avg_timediff           []
# has_zero                0
# Name: 187301, dtype: object
# source_id       367785737
# avg_timediff           []
# has_zero                0
# Name: 187506, dtype: object
# source_id       367785929
# avg_timediff           []
# has_zero                0
# Name: 187643, dtype: object
# source_id       367785946
# avg_timediff           []
# has_zero                0
# Name: 187658, dtype: object
# source_id       367786214
# avg_timediff           []
# has_zero                0
# Name: 187867, dtype: object
# source_id       367786394
# avg_timediff           []
# has_zero                0
# Name: 187962, dtype: object
# source_id       367786580
# avg_timediff           []
# has_zero                0
# Name: 188099, dtype: object
# source_id       367786640
# avg_timediff           []
# has_zero                0
# Name: 188142, dtype: object
# source_id       367786653
# avg_timediff           []
# has_zero                0
# Name: 188155, dtype: object
# source_id       367786682
# avg_timediff           []
# has_zero                0
# Name: 188184, dtype: object
# source_id       367786706
# avg_timediff           []
# has_zero                0
# Name: 188208, dtype: object
# source_id       367786837
# avg_timediff           []
# has_zero                0
# Name: 188313, dtype: object
# source_id       367787088
# avg_timediff           []
# has_zero                0
# Name: 188516, dtype: object
# source_id       367787118
# avg_timediff           []
# has_zero                0
# Name: 188524, dtype: object
# source_id       367787291
# avg_timediff           []
# has_zero                0
# Name: 188660, dtype: object
# source_id       367787384
# avg_timediff           []
# has_zero                0
# Name: 188738, dtype: object
# source_id       367787470
# avg_timediff           []
# has_zero                0
# Name: 188821, dtype: object
# source_id       367787516
# avg_timediff           []
# has_zero                0
# Name: 188823, dtype: object
# source_id       367787550
# avg_timediff           []
# has_zero                0
# Name: 188857, dtype: object
# source_id       367787855
# avg_timediff           []
# has_zero                0
# Name: 189112, dtype: object
# source_id       367787880
# avg_timediff           []
# has_zero                0
# Name: 189114, dtype: object
# source_id       367788161
# avg_timediff           []
# has_zero                0
# Name: 189262, dtype: object
# source_id       367788199
# avg_timediff           []
# has_zero                0
# Name: 189297, dtype: object
# source_id       367788263
# avg_timediff           []
# has_zero                0
# Name: 189346, dtype: object
# source_id       367788388
# avg_timediff           []
# has_zero                0
# Name: 189440, dtype: object
# source_id       367788602
# avg_timediff           []
# has_zero                0
# Name: 189623, dtype: object
# source_id       367788960
# avg_timediff           []
# has_zero                0
# Name: 189894, dtype: object
# source_id       367789076
# avg_timediff           []
# has_zero                0
# Name: 189961, dtype: object
# source_id       367789098
# avg_timediff           []
# has_zero                0
# Name: 189968, dtype: object
# source_id       367789208
# avg_timediff           []
# has_zero                0
# Name: 190070, dtype: object
# source_id       367789209
# avg_timediff           []
# has_zero                0
# Name: 190071, dtype: object
# source_id       367789220
# avg_timediff           []
# has_zero                0
# Name: 190076, dtype: object
# source_id       367789227
# avg_timediff           []
# has_zero                0
# Name: 190078, dtype: object
# source_id       367789414
# avg_timediff           []
# has_zero                0
# Name: 190254, dtype: object
# source_id       367789459
# avg_timediff           []
# has_zero                0
# Name: 190284, dtype: object
# source_id       367789545
# avg_timediff           []
# has_zero                0
# Name: 190320, dtype: object
# source_id       367789697
# avg_timediff           []
# has_zero                0
# Name: 190451, dtype: object
# source_id       367789733
# avg_timediff           []
# has_zero                0
# Name: 190477, dtype: object
# source_id       367789947
# avg_timediff           []
# has_zero                0
# Name: 190658, dtype: object
# source_id       367790068
# avg_timediff           []
# has_zero                0
# Name: 190763, dtype: object
# source_id       367790069
# avg_timediff           []
# has_zero                0
# Name: 190764, dtype: object
# source_id       367790328
# avg_timediff           []
# has_zero                0
# Name: 190952, dtype: object
# source_id       367790635
# avg_timediff           []
# has_zero                0
# Name: 191133, dtype: object
# source_id       367790642
# avg_timediff           []
# has_zero                0
# Name: 191134, dtype: object
# source_id       367790815
# avg_timediff           []
# has_zero                0
# Name: 191204, dtype: object
# source_id       367790855
# avg_timediff           []
# has_zero                0
# Name: 191244, dtype: object
# source_id       367790864
# avg_timediff           []
# has_zero                0
# Name: 191245, dtype: object
# source_id       367790974
# avg_timediff           []
# has_zero                0
# Name: 191347, dtype: object
# source_id       367790992
# avg_timediff           []
# has_zero                0
# Name: 191350, dtype: object
# source_id       367791209
# avg_timediff           []
# has_zero                0
# Name: 191557, dtype: object
# source_id       367791321
# avg_timediff           []
# has_zero                0
# Name: 191662, dtype: object
# source_id       367791431
# avg_timediff           []
# has_zero                0
# Name: 191759, dtype: object
# source_id       367791504
# avg_timediff           []
# has_zero                0
# Name: 191830, dtype: object
# source_id       367791763
# avg_timediff           []
# has_zero                0
# Name: 191969, dtype: object
# source_id       367659680
# avg_timediff           []
# has_zero                0
# Name: 203991, dtype: object
# source_id       367689630
# avg_timediff           []
# has_zero                0
# Name: 205056, dtype: object
# source_id       367711544
# avg_timediff           []
# has_zero                0
# Name: 205748, dtype: object
# source_id       367715896
# avg_timediff           []
# has_zero                0
# Name: 205840, dtype: object
# source_id       367723080
# avg_timediff           []
# has_zero                0
# Name: 205990, dtype: object
# source_id       367725985
# avg_timediff           []
# has_zero                0
# Name: 206095, dtype: object
# source_id       367726021
# avg_timediff           []
# has_zero                0
# Name: 206102, dtype: object
# source_id       367726358
# avg_timediff           []
# has_zero                0
# Name: 206155, dtype: object
# source_id       367726369
# avg_timediff           []
# has_zero                0
# Name: 206157, dtype: object
# source_id       367726480
# avg_timediff           []
# has_zero                0
# Name: 206189, dtype: object
# source_id       367726716
# avg_timediff           []
# has_zero                0
# Name: 206253, dtype: object
# source_id       367726808
# avg_timediff           []
# has_zero                0
# Name: 206273, dtype: object
# source_id       367726948
# avg_timediff           []
# has_zero                0
# Name: 206319, dtype: object
# source_id       367726960
# avg_timediff           []
# has_zero                0
# Name: 206330, dtype: object
# source_id       367727119
# avg_timediff           []
# has_zero                0
# Name: 206371, dtype: object
# source_id       367727154
# avg_timediff           []
# has_zero                0
# Name: 206375, dtype: object
# source_id       367727160
# avg_timediff           []
# has_zero                0
# Name: 206379, dtype: object
# source_id       367727179
# avg_timediff           []
# has_zero                0
# Name: 206391, dtype: object
# source_id       367727212
# avg_timediff           []
# has_zero                0
# Name: 206400, dtype: object
# source_id       367727224
# avg_timediff           []
# has_zero                0
# Name: 206411, dtype: object
# source_id       367727300
# avg_timediff           []
# has_zero                0
# Name: 206419, dtype: object
# source_id       367727305
# avg_timediff           []
# has_zero                0
# Name: 206422, dtype: object
# source_id       367727354
# avg_timediff           []
# has_zero                0
# Name: 206440, dtype: object
# source_id       367727465
# avg_timediff           []
# has_zero                0
# Name: 206476, dtype: object
# source_id       367727557
# avg_timediff           []
# has_zero                0
# Name: 206506, dtype: object
# source_id       367727666
# avg_timediff           []
# has_zero                0
# Name: 206513, dtype: object
# source_id       367727895
# avg_timediff           []
# has_zero                0
# Name: 206587, dtype: object
# source_id       367727960
# avg_timediff           []
# has_zero                0
# Name: 206597, dtype: object
# source_id       367728034
# avg_timediff           []
# has_zero                0
# Name: 206620, dtype: object
# source_id       367728041
# avg_timediff           []
# has_zero                0
# Name: 206622, dtype: object
# source_id       367728234
# avg_timediff           []
# has_zero                0
# Name: 206676, dtype: object
# source_id       367728436
# avg_timediff           []
# has_zero                0
# Name: 206745, dtype: object
# source_id       367728574
# avg_timediff           []
# has_zero                0
# Name: 206791, dtype: object
# source_id       367729312
# avg_timediff           []
# has_zero                0
# Name: 206998, dtype: object
# source_id       367729655
# avg_timediff           []
# has_zero                0
# Name: 207111, dtype: object
# source_id       367729894
# avg_timediff           []
# has_zero                0
# Name: 207176, dtype: object
# source_id       367729932
# avg_timediff           []
# has_zero                0
# Name: 207184, dtype: object
# source_id       367729976
# avg_timediff           []
# has_zero                0
# Name: 207192, dtype: object
# source_id       367730004
# avg_timediff           []
# has_zero                0
# Name: 207207, dtype: object
# source_id       367730091
# avg_timediff           []
# has_zero                0
# Name: 207229, dtype: object
# source_id       367730147
# avg_timediff           []
# has_zero                0
# Name: 207244, dtype: object
# source_id       367730201
# avg_timediff           []
# has_zero                0
# Name: 207250, dtype: object
# source_id       367730234
# avg_timediff           []
# has_zero                0
# Name: 207263, dtype: object
# source_id       367730292
# avg_timediff           []
# has_zero                0
# Name: 207276, dtype: object
# source_id       367730352
# avg_timediff           []
# has_zero                0
# Name: 207287, dtype: object
# source_id       367730667
# avg_timediff           []
# has_zero                0
# Name: 207373, dtype: object
# source_id       367730672
# avg_timediff           []
# has_zero                0
# Name: 207376, dtype: object
# source_id       367730794
# avg_timediff           []
# has_zero                0
# Name: 207408, dtype: object
# source_id       367730858
# avg_timediff           []
# has_zero                0
# Name: 207413, dtype: object
# source_id       367730950
# avg_timediff           []
# has_zero                0
# Name: 207434, dtype: object
# source_id       367731080
# avg_timediff           []
# has_zero                0
# Name: 207472, dtype: object
# source_id       367731117
# avg_timediff           []
# has_zero                0
# Name: 207484, dtype: object
# source_id       367731120
# avg_timediff           []
# has_zero                0
# Name: 207485, dtype: object
# source_id       367731148
# avg_timediff           []
# has_zero                0
# Name: 207488, dtype: object
# source_id       367731199
# avg_timediff           []
# has_zero                0
# Name: 207490, dtype: object
# source_id       367731206
# avg_timediff           []
# has_zero                0
# Name: 207493, dtype: object
# source_id       367731410
# avg_timediff           []
# has_zero                0
# Name: 207541, dtype: object
# source_id       367731599
# avg_timediff           []
# has_zero                0
# Name: 207604, dtype: object
# source_id       367731663
# avg_timediff           []
# has_zero                0
# Name: 207611, dtype: object
# source_id       367731672
# avg_timediff           []
# has_zero                0
# Name: 207619, dtype: object
# source_id       367731768
# avg_timediff           []
# has_zero                0
# Name: 207646, dtype: object
# source_id       367731837
# avg_timediff           []
# has_zero                0
# Name: 207667, dtype: object
# source_id       367731927
# avg_timediff           []
# has_zero                0
# Name: 207685, dtype: object
# source_id       367732021
# avg_timediff           []
# has_zero                0
# Name: 207703, dtype: object
# source_id       367732111
# avg_timediff           []
# has_zero                0
# Name: 207734, dtype: object
# source_id       367732118
# avg_timediff           []
# has_zero                0
# Name: 207736, dtype: object
# source_id       367732120
# avg_timediff           []
# has_zero                0
# Name: 207737, dtype: object
# source_id       367732129
# avg_timediff           []
# has_zero                0
# Name: 207738, dtype: object
# source_id       367732252
# avg_timediff           []
# has_zero                0
# Name: 207759, dtype: object
# source_id       367732253
# avg_timediff           []
# has_zero                0
# Name: 207760, dtype: object
# source_id       367732282
# avg_timediff           []
# has_zero                0
# Name: 207765, dtype: object
# source_id       367732446
# avg_timediff           []
# has_zero                0
# Name: 207819, dtype: object
# source_id       367732464
# avg_timediff           []
# has_zero                0
# Name: 207824, dtype: object
# source_id       367732512
# avg_timediff           []
# has_zero                0
# Name: 207836, dtype: object
# source_id       367732639
# avg_timediff           []
# has_zero                0
# Name: 207872, dtype: object
# source_id       367732642
# avg_timediff           []
# has_zero                0
# Name: 207874, dtype: object
# source_id       367732670
# avg_timediff           []
# has_zero                0
# Name: 207879, dtype: object
# source_id       367732854
# avg_timediff           []
# has_zero                0
# Name: 207904, dtype: object
# source_id       367732857
# avg_timediff           []
# has_zero                0
# Name: 207905, dtype: object
# source_id       367732937
# avg_timediff           []
# has_zero                0
# Name: 207926, dtype: object
# source_id       367732987
# avg_timediff           []
# has_zero                0
# Name: 207940, dtype: object
# source_id       367733050
# avg_timediff           []
# has_zero                0
# Name: 207952, dtype: object
# source_id       367733302
# avg_timediff           []
# has_zero                0
# Name: 207993, dtype: object
# source_id       367733451
# avg_timediff           []
# has_zero                0
# Name: 208031, dtype: object
# source_id       367733581
# avg_timediff           []
# has_zero                0
# Name: 208077, dtype: object
# source_id       367733586
# avg_timediff           []
# has_zero                0
# Name: 208081, dtype: object
# source_id       367733595
# avg_timediff           []
# has_zero                0
# Name: 208086, dtype: object
# source_id       367734093
# avg_timediff           []
# has_zero                0
# Name: 208185, dtype: object
# source_id       367734190
# avg_timediff           []
# has_zero                0
# Name: 208194, dtype: object
# source_id       367734808
# avg_timediff           []
# has_zero                0
# Name: 208340, dtype: object
# source_id       367734868
# avg_timediff           []
# has_zero                0
# Name: 208355, dtype: object
# source_id       367734933
# avg_timediff           []
# has_zero                0
# Name: 208370, dtype: object
# source_id       367734957
# avg_timediff           []
# has_zero                0
# Name: 208383, dtype: object
# source_id       367734968
# avg_timediff           []
# has_zero                0
# Name: 208384, dtype: object
# source_id       367735024
# avg_timediff           []
# has_zero                0
# Name: 208400, dtype: object
# source_id       367735052
# avg_timediff           []
# has_zero                0
# Name: 208406, dtype: object
# source_id       367735279
# avg_timediff           []
# has_zero                0
# Name: 208453, dtype: object
# source_id       367735343
# avg_timediff           []
# has_zero                0
# Name: 208461, dtype: object
# source_id       367735376
# avg_timediff           []
# has_zero                0
# Name: 208464, dtype: object
# source_id       367735440
# avg_timediff           []
# has_zero                0
# Name: 208481, dtype: object
# source_id       367735510
# avg_timediff           []
# has_zero                0
# Name: 208498, dtype: object
# source_id       367735585
# avg_timediff           []
# has_zero                0
# Name: 208519, dtype: object
# source_id       367735589
# avg_timediff           []
# has_zero                0
# Name: 208522, dtype: object
# source_id       367735776
# avg_timediff           []
# has_zero                0
# Name: 208548, dtype: object
# source_id       367735868
# avg_timediff           []
# has_zero                0
# Name: 208566, dtype: object
# source_id       367735907
# avg_timediff           []
# has_zero                0
# Name: 208569, dtype: object
# source_id       367736053
# avg_timediff           []
# has_zero                0
# Name: 208597, dtype: object
# source_id       367736082
# avg_timediff           []
# has_zero                0
# Name: 208599, dtype: object
# source_id       367736084
# avg_timediff           []
# has_zero                0
# Name: 208600, dtype: object
# source_id       367736088
# avg_timediff           []
# has_zero                0
# Name: 208601, dtype: object
# source_id       367736106
# avg_timediff           []
# has_zero                0
# Name: 208612, dtype: object
# source_id       367736415
# avg_timediff           []
# has_zero                0
# Name: 208665, dtype: object
# source_id       367736499
# avg_timediff           []
# has_zero                0
# Name: 208682, dtype: object
# source_id       367736505
# avg_timediff           []
# has_zero                0
# Name: 208683, dtype: object
# source_id       367736507
# avg_timediff           []
# has_zero                0
# Name: 208684, dtype: object
# source_id       367736545
# avg_timediff           []
# has_zero                0
# Name: 208688, dtype: object
# source_id       367736586
# avg_timediff           []
# has_zero                0
# Name: 208703, dtype: object
# source_id       367736806
# avg_timediff           []
# has_zero                0
# Name: 208745, dtype: object
# source_id       367737014
# avg_timediff           []
# has_zero                0
# Name: 208770, dtype: object
# source_id       367737078
# avg_timediff           []
# has_zero                0
# Name: 208783, dtype: object
# source_id       367737104
# avg_timediff           []
# has_zero                0
# Name: 208785, dtype: object
# source_id       367737147
# avg_timediff           []
# has_zero                0
# Name: 208801, dtype: object
# source_id       367737195
# avg_timediff           []
# has_zero                0
# Name: 208816, dtype: object
# source_id       367737228
# avg_timediff           []
# has_zero                0
# Name: 208820, dtype: object
# source_id       367737229
# avg_timediff           []
# has_zero                0
# Name: 208821, dtype: object
# source_id       367737388
# avg_timediff           []
# has_zero                0
# Name: 208857, dtype: object
# source_id       367737645
# avg_timediff           []
# has_zero                0
# Name: 208906, dtype: object
# source_id       367737685
# avg_timediff           []
# has_zero                0
# Name: 208911, dtype: object
# source_id       367737737
# avg_timediff           []
# has_zero                0
# Name: 208925, dtype: object
# source_id       367737787
# avg_timediff           []
# has_zero                0
# Name: 208940, dtype: object
# source_id       367738057
# avg_timediff           []
# has_zero                0
# Name: 208993, dtype: object
# source_id       367738135
# avg_timediff           []
# has_zero                0
# Name: 209005, dtype: object
# source_id       367738225
# avg_timediff           []
# has_zero                0
# Name: 209016, dtype: object
# source_id       367738844
# avg_timediff           []
# has_zero                0
# Name: 209073, dtype: object
# source_id       367746778
# avg_timediff           []
# has_zero                0
# Name: 209075, dtype: object
# source_id       367749266
# avg_timediff           []
# has_zero                0
# Name: 209111, dtype: object
# source_id       367749357
# avg_timediff           []
# has_zero                0
# Name: 209153, dtype: object
# source_id       367749361
# avg_timediff           []
# has_zero                0
# Name: 209155, dtype: object
# source_id       367749698
# avg_timediff           []
# has_zero                0
# Name: 209275, dtype: object
# source_id       367749720
# avg_timediff           []
# has_zero                0
# Name: 209288, dtype: object
# source_id       367750085
# avg_timediff           []
# has_zero                0
# Name: 209427, dtype: object
# source_id       367750266
# avg_timediff           []
# has_zero                0
# Name: 209481, dtype: object
# source_id       367750271
# avg_timediff           []
# has_zero                0
# Name: 209485, dtype: object
# source_id       367750563
# avg_timediff           []
# has_zero                0
# Name: 209550, dtype: object
# source_id       367750615
# avg_timediff           []
# has_zero                0
# Name: 209575, dtype: object
# source_id       367750623
# avg_timediff           []
# has_zero                0
# Name: 209577, dtype: object
# source_id       367750676
# avg_timediff           []
# has_zero                0
# Name: 209599, dtype: object
# source_id       367750698
# avg_timediff           []
# has_zero                0
# Name: 209605, dtype: object
# source_id       367750790
# avg_timediff           []
# has_zero                0
# Name: 209638, dtype: object
# source_id       367750810
# avg_timediff           []
# has_zero                0
# Name: 209641, dtype: object
# source_id       367750845
# avg_timediff           []
# has_zero                0
# Name: 209656, dtype: object
# source_id       367750911
# avg_timediff           []
# has_zero                0
# Name: 209686, dtype: object
# source_id       367751098
# avg_timediff           []
# has_zero                0
# Name: 209737, dtype: object
# source_id       367751128
# avg_timediff           []
# has_zero                0
# Name: 209742, dtype: object
# source_id       367751154
# avg_timediff           []
# has_zero                0
# Name: 209755, dtype: object
# source_id       367751155
# avg_timediff           []
# has_zero                0
# Name: 209756, dtype: object
# source_id       367751175
# avg_timediff           []
# has_zero                0
# Name: 209758, dtype: object
# source_id       367751308
# avg_timediff           []
# has_zero                0
# Name: 209798, dtype: object
# source_id       367751349
# avg_timediff           []
# has_zero                0
# Name: 209804, dtype: object
# source_id       367751358
# avg_timediff           []
# has_zero                0
# Name: 209806, dtype: object
# source_id       367751420
# avg_timediff           []
# has_zero                0
# Name: 209825, dtype: object
# source_id       367751453
# avg_timediff           []
# has_zero                0
# Name: 209838, dtype: object
# source_id       367751519
# avg_timediff           []
# has_zero                0
# Name: 209850, dtype: object
# source_id       367751539
# avg_timediff           []
# has_zero                0
# Name: 209861, dtype: object
# source_id       367751551
# avg_timediff           []
# has_zero                0
# Name: 209868, dtype: object
# source_id       367751554
# avg_timediff           []
# has_zero                0
# Name: 209869, dtype: object
# source_id       367751575
# avg_timediff           []
# has_zero                0
# Name: 209872, dtype: object
# source_id       367751649
# avg_timediff           []
# has_zero                0
# Name: 209901, dtype: object
# source_id       367751684
# avg_timediff           []
# has_zero                0
# Name: 209907, dtype: object
# source_id       367751702
# avg_timediff           []
# has_zero                0
# Name: 209909, dtype: object
# source_id       367751737
# avg_timediff           []
# has_zero                0
# Name: 209921, dtype: object
# source_id       367751742
# avg_timediff           []
# has_zero                0
# Name: 209923, dtype: object
# source_id       367751870
# avg_timediff           []
# has_zero                0
# Name: 209953, dtype: object
# source_id       367751905
# avg_timediff           []
# has_zero                0
# Name: 209960, dtype: object
# source_id       367751946
# avg_timediff           []
# has_zero                0
# Name: 209978, dtype: object
# source_id       367751949
# avg_timediff           []
# has_zero                0
# Name: 209979, dtype: object
# source_id       367751967
# avg_timediff           []
# has_zero                0
# Name: 209981, dtype: object
# source_id       367751969
# avg_timediff           []
# has_zero                0
# Name: 209982, dtype: object
# source_id       367751977
# avg_timediff           []
# has_zero                0
# Name: 209983, dtype: object
# source_id       367751983
# avg_timediff           []
# has_zero                0
# Name: 209984, dtype: object
# source_id       367752006
# avg_timediff           []
# has_zero                0
# Name: 209985, dtype: object
# source_id       367752225
# avg_timediff           []
# has_zero                0
# Name: 210044, dtype: object
# source_id       367752252
# avg_timediff           []
# has_zero                0
# Name: 210056, dtype: object
# source_id       367752328
# avg_timediff           []
# has_zero                0
# Name: 210068, dtype: object
# source_id       367752341
# avg_timediff           []
# has_zero                0
# Name: 210079, dtype: object
# source_id       367752377
# avg_timediff           []
# has_zero                0
# Name: 210086, dtype: object
# source_id       367752395
# avg_timediff           []
# has_zero                0
# Name: 210088, dtype: object
# source_id       367752475
# avg_timediff           []
# has_zero                0
# Name: 210117, dtype: object
# source_id       367752518
# avg_timediff           []
# has_zero                0
# Name: 210124, dtype: object
# source_id       367752519
# avg_timediff           []
# has_zero                0
# Name: 210125, dtype: object
# source_id       367752562
# avg_timediff           []
# has_zero                0
# Name: 210143, dtype: object
# source_id       367752571
# avg_timediff           []
# has_zero                0
# Name: 210144, dtype: object
# source_id       367752590
# avg_timediff           []
# has_zero                0
# Name: 210148, dtype: object
# source_id       367752630
# avg_timediff           []
# has_zero                0
# Name: 210153, dtype: object
# source_id       367752668
# avg_timediff           []
# has_zero                0
# Name: 210168, dtype: object
# source_id       367752813
# avg_timediff           []
# has_zero                0
# Name: 210223, dtype: object
# source_id       367752851
# avg_timediff           []
# has_zero                0
# Name: 210227, dtype: object
# source_id       367752924
# avg_timediff           []
# has_zero                0
# Name: 210246, dtype: object
# source_id       367752925
# avg_timediff           []
# has_zero                0
# Name: 210247, dtype: object
# source_id       367752943
# avg_timediff           []
# has_zero                0
# Name: 210254, dtype: object
# source_id       367752945
# avg_timediff           []
# has_zero                0
# Name: 210256, dtype: object
# source_id       367752975
# avg_timediff           []
# has_zero                0
# Name: 210265, dtype: object
# source_id       367753084
# avg_timediff           []
# has_zero                0
# Name: 210303, dtype: object
# source_id       367753096
# avg_timediff           []
# has_zero                0
# Name: 210304, dtype: object
# source_id       367753121
# avg_timediff           []
# has_zero                0
# Name: 210319, dtype: object
# source_id       367753194
# avg_timediff           []
# has_zero                0
# Name: 210333, dtype: object
# source_id       367753195
# avg_timediff           []
# has_zero                0
# Name: 210334, dtype: object
# source_id       367753281
# avg_timediff           []
# has_zero                0
# Name: 210351, dtype: object
# source_id       367753322
# avg_timediff           []
# has_zero                0
# Name: 210373, dtype: object
# source_id       367753326
# avg_timediff           []
# has_zero                0
# Name: 210377, dtype: object
# source_id       367753327
# avg_timediff           []
# has_zero                0
# Name: 210378, dtype: object
# source_id       367753335
# avg_timediff           []
# has_zero                0
# Name: 210383, dtype: object
# source_id       367753384
# avg_timediff           []
# has_zero                0
# Name: 210396, dtype: object
# source_id       367753870
# avg_timediff           []
# has_zero                0
# Name: 210635, dtype: object
# source_id       367754033
# avg_timediff           []
# has_zero                0
# Name: 210695, dtype: object
# source_id       367754048
# avg_timediff           []
# has_zero                0
# Name: 210697, dtype: object
# source_id       367754060
# avg_timediff           []
# has_zero                0
# Name: 210708, dtype: object
# source_id       367754068
# avg_timediff           []
# has_zero                0
# Name: 210709, dtype: object
# source_id       367754120
# avg_timediff           []
# has_zero                0
# Name: 210734, dtype: object
# source_id       367754155
# avg_timediff           []
# has_zero                0
# Name: 210749, dtype: object
# source_id       367754173
# avg_timediff           []
# has_zero                0
# Name: 210753, dtype: object
# source_id       367754228
# avg_timediff           []
# has_zero                0
# Name: 210766, dtype: object
# source_id       367754351
# avg_timediff           []
# has_zero                0
# Name: 210803, dtype: object
# source_id       367754356
# avg_timediff           []
# has_zero                0
# Name: 210804, dtype: object
# source_id       367754362
# avg_timediff           []
# has_zero                0
# Name: 210805, dtype: object
# source_id       367754612
# avg_timediff           []
# has_zero                0
# Name: 210954, dtype: object
# source_id       367754792
# avg_timediff           []
# has_zero                0
# Name: 211100, dtype: object
# source_id       367755125
# avg_timediff           []
# has_zero                0
# Name: 211352, dtype: object
# source_id       367755127
# avg_timediff           []
# has_zero                0
# Name: 211354, dtype: object
# source_id       367755553
# avg_timediff           []
# has_zero                0
# Name: 211628, dtype: object
# source_id       367755605
# avg_timediff           []
# has_zero                0
# Name: 211658, dtype: object
# source_id       367755639
# avg_timediff           []
# has_zero                0
# Name: 211692, dtype: object
# source_id       367755705
# avg_timediff           []
# has_zero                0
# Name: 211738, dtype: object
# source_id       367755710
# avg_timediff           []
# has_zero                0
# Name: 211739, dtype: object
# source_id       367755834
# avg_timediff           []
# has_zero                0
# Name: 211788, dtype: object
# source_id       367755864
# avg_timediff           []
# has_zero                0
# Name: 211790, dtype: object
# source_id       367756002
# avg_timediff           []
# has_zero                0
# Name: 211884, dtype: object
# source_id       367756003
# avg_timediff           []
# has_zero                0
# Name: 211885, dtype: object
# source_id       367756008
# avg_timediff           []
# has_zero                0
# Name: 211886, dtype: object
# source_id       367756130
# avg_timediff           []
# has_zero                0
# Name: 211991, dtype: object
# source_id       367756285
# avg_timediff           []
# has_zero                0
# Name: 212105, dtype: object
# source_id       367756408
# avg_timediff           []
# has_zero                0
# Name: 212210, dtype: object
# source_id       367756410
# avg_timediff           []
# has_zero                0
# Name: 212211, dtype: object
# source_id       367756419
# avg_timediff           []
# has_zero                0
# Name: 212212, dtype: object
# source_id       367756538
# avg_timediff           []
# has_zero                0
# Name: 212318, dtype: object
# source_id       367756550
# avg_timediff           []
# has_zero                0
# Name: 212319, dtype: object
# source_id       367756982
# avg_timediff           []
# has_zero                0
# Name: 212650, dtype: object
# source_id       367757118
# avg_timediff           []
# has_zero                0
# Name: 212749, dtype: object
# source_id       367757225
# avg_timediff           []
# has_zero                0
# Name: 212851, dtype: object
# source_id       367757569
# avg_timediff           []
# has_zero                0
# Name: 213110, dtype: object
# source_id       367757696
# avg_timediff           []
# has_zero                0
# Name: 213190, dtype: object
# source_id       367757925
# avg_timediff           []
# has_zero                0
# Name: 213379, dtype: object
# source_id       367758118
# avg_timediff           []
# has_zero                0
# Name: 213523, dtype: object
# source_id       367758217
# avg_timediff           []
# has_zero                0
# Name: 213604, dtype: object
# source_id       367758811
# avg_timediff           []
# has_zero                0
# Name: 214106, dtype: object
# source_id       367758931
# avg_timediff           []
# has_zero                0
# ...
# avg_timediff           []
# has_zero                0
# Name: 273524, dtype: object
# source_id       365845572
# avg_timediff           []
# has_zero                0
# Name: 284888, dtype: object
# source_id       367287633
# avg_timediff           []
# has_zero                0
# Name: 289065, dtype: object
# source_id       367290381
# avg_timediff           []
# has_zero                0
# Name: 289175, dtype: object
# source_id       367388086
# avg_timediff           []
# has_zero                0
# Name: 292956, dtype: object
# source_id       367391527
# avg_timediff           []
# has_zero                0
# Name: 293128, dtype: object
# source_id       367416438
# avg_timediff           []
# has_zero                0
# Name: 294171, dtype: object
# source_id       367416758
# avg_timediff           []
# has_zero                0
# Name: 294196, dtype: object
# source_id       367425079
# avg_timediff           []
# has_zero                0
# Name: 294535, dtype: object
# source_id       367492968
# avg_timediff           []
# has_zero                0
# Name: 295484, dtype: object
# source_id       367496766
# avg_timediff           []
# has_zero                0
# Name: 295675, dtype: object
# source_id       367496768
# avg_timediff           []
# has_zero                0
# Name: 295676, dtype: object
# source_id       367510009
# avg_timediff           []
# has_zero                0
# Name: 296218, dtype: object
# source_id       367510063
# avg_timediff           []
# has_zero                0
# Name: 296221, dtype: object
# source_id       367511998
# avg_timediff           []
# has_zero                0
# Name: 296313, dtype: object
# source_id       367539664
# avg_timediff           []
# has_zero                0
# Name: 296354, dtype: object
# source_id       367558470
# avg_timediff           []
# has_zero                0
# Name: 296438, dtype: object
# source_id       367584529
# avg_timediff           []
# has_zero                0
# Name: 296957, dtype: object
# source_id       367585322
# avg_timediff           []
# has_zero                0
# Name: 297004, dtype: object
# source_id       367585851
# avg_timediff           []
# has_zero                0
# Name: 297026, dtype: object
# source_id       367589647
# avg_timediff           []
# has_zero                0
# Name: 297141, dtype: object
# source_id       367597774
# avg_timediff           []
# has_zero                0
# Name: 297169, dtype: object
# source_id       367599652
# avg_timediff           []
# has_zero                0
# Name: 297177, dtype: object
# source_id       367677692
# avg_timediff           []
# has_zero                0
# Name: 298082, dtype: object
# source_id       367680293
# avg_timediff           []
# has_zero                0
# Name: 298233, dtype: object
# source_id       367680327
# avg_timediff           []
# has_zero                0
# Name: 298234, dtype: object
# source_id       367682345
# avg_timediff           []
# has_zero                0
# Name: 298370, dtype: object
# source_id       367682411
# avg_timediff           []
# has_zero                0
# Name: 298374, dtype: object
# source_id       367683411
# avg_timediff           []
# has_zero                0
# Name: 298436, dtype: object
# source_id       367684996
# avg_timediff           []
# has_zero                0
# Name: 298503, dtype: object
# source_id       367685347
# avg_timediff           []
# has_zero                0
# Name: 298515, dtype: object
# source_id       367701178
# avg_timediff           []
# has_zero                0
# Name: 298588, dtype: object
# source_id       367701179
# avg_timediff           []
# has_zero                0
# Name: 298589, dtype: object
# source_id       367701494
# avg_timediff           []
# has_zero                0
# Name: 298630, dtype: object
# source_id       367701957
# avg_timediff           []
# has_zero                0
# Name: 298704, dtype: object
# source_id       367702334
# avg_timediff           []
# has_zero                0
# Name: 298761, dtype: object
# source_id       367702587
# avg_timediff           []
# has_zero                0
# Name: 298792, dtype: object
# source_id       367702729
# avg_timediff           []
# has_zero                0
# Name: 298823, dtype: object
# source_id       367703037
# avg_timediff           []
# has_zero                0
# Name: 298872, dtype: object
# source_id       367294002
# avg_timediff           []
# has_zero                0
# Name: 318937, dtype: object
# source_id       367294424
# avg_timediff           []
# has_zero                0
# Name: 318978, dtype: object
# source_id       367317682
# avg_timediff           []
# has_zero                0
# Name: 319570, dtype: object
# source_id       367317942
# avg_timediff           []
# has_zero                0
# Name: 319602, dtype: object
# source_id       367318993
# avg_timediff           []
# has_zero                0
# Name: 319702, dtype: object
# source_id       367319724
# avg_timediff           []
# has_zero                0
# Name: 319784, dtype: object
# source_id       367337724
# avg_timediff           []
# has_zero                0
# Name: 320445, dtype: object
# source_id       367356842
# avg_timediff           []
# has_zero                0
# Name: 320727, dtype: object
# source_id       367362175
# avg_timediff           []
# has_zero                0
# Name: 320955, dtype: object
# source_id       367362390
# avg_timediff           []
# has_zero                0
# Name: 320969, dtype: object
# source_id       367362566
# avg_timediff           []
# has_zero                0
# Name: 320982, dtype: object
# source_id       367362856
# avg_timediff           []
# has_zero                0
# Name: 320995, dtype: object
# source_id       367363488
# avg_timediff           []
# has_zero                0
# Name: 321048, dtype: object
# source_id       367363536
# avg_timediff           []
# has_zero                0
# Name: 321050, dtype: object
# source_id       367363631
# avg_timediff           []
# has_zero                0
# Name: 321056, dtype: object
# source_id       367364545
# avg_timediff           []
# has_zero                0
# Name: 321124, dtype: object
# source_id       367364653
# avg_timediff           []
# has_zero                0
# Name: 321131, dtype: object
# source_id       367365055
# avg_timediff           []
# has_zero                0
# Name: 321164, dtype: object
# source_id       367365930
# avg_timediff           []
# has_zero                0
# Name: 321235, dtype: object
# source_id       367366477
# avg_timediff           []
# has_zero                0
# Name: 321290, dtype: object
# source_id       367368145
# avg_timediff           []
# has_zero                0
# Name: 321460, dtype: object
# source_id       367368163
# avg_timediff           []
# has_zero                0
# Name: 321471, dtype: object
# source_id       367369596
# avg_timediff           []
# has_zero                0
# Name: 321614, dtype: object
# source_id       367369661
# avg_timediff           []
# has_zero                0
# Name: 321617, dtype: object
# source_id       367370021
# avg_timediff           []
# has_zero                0
# Name: 321640, dtype: object
# source_id       367386501
# avg_timediff           []
# has_zero                0
# Name: 322081, dtype: object
# source_id       367387235
# avg_timediff           []
# has_zero                0
# Name: 322120, dtype: object
# source_id       367388138
# avg_timediff           []
# has_zero                0
# Name: 322192, dtype: object
# source_id       367388213
# avg_timediff           []
# has_zero                0
# Name: 322197, dtype: object
# source_id       367388780
# avg_timediff           []
# has_zero                0
# Name: 322233, dtype: object
# source_id       367389260
# avg_timediff           []
# has_zero                0
# Name: 322256, dtype: object
# source_id       367389794
# avg_timediff           []
# has_zero                0
# Name: 322285, dtype: object
# source_id       367389845
# avg_timediff           []
# has_zero                0
# Name: 322286, dtype: object
# source_id       367390340
# avg_timediff           []
# has_zero                0
# Name: 322313, dtype: object
# source_id       367390993
# avg_timediff           []
# has_zero                0
# Name: 322361, dtype: object
# source_id       367391131
# avg_timediff           []
# has_zero                0
# Name: 322364, dtype: object
# source_id       367391402
# avg_timediff           []
# has_zero                0
# Name: 322384, dtype: object
# source_id       367392145
# avg_timediff           []
# has_zero                0
# Name: 322462, dtype: object
# source_id       367392897
# avg_timediff           []
# has_zero                0
# Name: 322510, dtype: object
# source_id       367393071
# avg_timediff           []
# has_zero                0
# Name: 322528, dtype: object
# source_id       367393209
# avg_timediff           []
# has_zero                0
# Name: 322538, dtype: object
# source_id       367393224
# avg_timediff           []
# has_zero                0
# Name: 322549, dtype: object
# source_id       367393900
# avg_timediff           []
# has_zero                0
# Name: 322602, dtype: object
# source_id       367395243
# avg_timediff           []
# has_zero                0
# Name: 322725, dtype: object
# source_id       367395615
# avg_timediff           []
# has_zero                0
# Name: 322755, dtype: object
# source_id       367396328
# avg_timediff           []
# has_zero                0
# Name: 322801, dtype: object
# source_id       367396686
# avg_timediff           []
# has_zero                0
# Name: 322817, dtype: object
# source_id       367396880
# avg_timediff           []
# has_zero                0
# Name: 322825, dtype: object
# source_id       367411160
# avg_timediff           []
# has_zero                0
# Name: 323111, dtype: object
# source_id       367411798
# avg_timediff           []
# has_zero                0
# Name: 323128, dtype: object
# source_id       367412418
# avg_timediff           []
# has_zero                0
# Name: 323170, dtype: object
# source_id       367412420
# avg_timediff           []
# has_zero                0
# Name: 323171, dtype: object
# source_id       367416784
# avg_timediff           []
# has_zero                0
# Name: 323300, dtype: object
# source_id       367417445
# avg_timediff           []
# has_zero                0
# Name: 323324, dtype: object
# source_id       367418618
# avg_timediff           []
# has_zero                0
# Name: 323354, dtype: object
# source_id       367422334
# avg_timediff           []
# has_zero                0
# Name: 323456, dtype: object
# source_id       367474994
# avg_timediff           []
# has_zero                0
# Name: 323803, dtype: object
# source_id       367478971
# avg_timediff           []
# has_zero                0
# Name: 323927, dtype: object
# source_id       367505519
# avg_timediff           []
# has_zero                0
# Name: 324168, dtype: object
# source_id       367287162
# avg_timediff           []
# has_zero                0
# Name: 334994, dtype: object
# source_id       367288756
# avg_timediff           []
# has_zero                0
# Name: 335055, dtype: object
# source_id       367288991
# avg_timediff           []
# has_zero                0
# Name: 335070, dtype: object
# source_id       367290033
# avg_timediff           []
# has_zero                0
# Name: 335137, dtype: object
# source_id       367290227
# avg_timediff           []
# has_zero                0
# Name: 335153, dtype: object
# source_id       367290342
# avg_timediff           []
# has_zero                0
# Name: 335165, dtype: object
# source_id       367290842
# avg_timediff           []
# has_zero                0
# Name: 335194, dtype: object
# source_id       367290994
# avg_timediff           []
# has_zero                0
# Name: 335200, dtype: object
# source_id       367291157
# avg_timediff           []
# has_zero                0
# Name: 335213, dtype: object
# source_id       367291451
# avg_timediff           []
# has_zero                0
# Name: 335225, dtype: object
# source_id       367291915
# avg_timediff           []
# has_zero                0
# Name: 335260, dtype: object
# source_id       367292039
# avg_timediff           []
# has_zero                0
# Name: 335274, dtype: object
# source_id       367292183
# avg_timediff           []
# has_zero                0
# Name: 335285, dtype: object
# source_id       367292910
# avg_timediff           []
# has_zero                0
# Name: 335333, dtype: object
# source_id       367292994
# avg_timediff           []
# has_zero                0
# Name: 335341, dtype: object
# source_id       367293640
# avg_timediff           []
# has_zero                0
# Name: 335396, dtype: object
# source_id       367312965
# avg_timediff           []
# has_zero                0
# Name: 335544, dtype: object
# source_id       367313225
# avg_timediff           []
# has_zero                0
# Name: 335554, dtype: object
# source_id       367315345
# avg_timediff           []
# has_zero                0
# Name: 335648, dtype: object
# source_id       367316445
# avg_timediff           []
# has_zero                0
# Name: 335681, dtype: object
# source_id       367335341
# avg_timediff           []
# has_zero                0
# Name: 335850, dtype: object
# source_id       367336168
# avg_timediff           []
# has_zero                0
# Name: 335885, dtype: object
# source_id       367336174
# avg_timediff           []
# has_zero                0
# Name: 335887, dtype: object
# source_id       367336296
# avg_timediff           []
# has_zero                0
# Name: 335894, dtype: object
# source_id       367337829
# avg_timediff           []
# has_zero                0
# Name: 335985, dtype: object
# source_id       367356848
# avg_timediff           []
# has_zero                0
# Name: 336073, dtype: object
# source_id       367357783
# avg_timediff           []
# has_zero                0
# Name: 336120, dtype: object
# source_id       367358083
# avg_timediff           []
# has_zero                0
# Name: 336149, dtype: object
# source_id       367358620
# avg_timediff           []
# has_zero                0
# Name: 336184, dtype: object
# source_id       367358729
# avg_timediff           []
# has_zero                0
# Name: 336189, dtype: object
# source_id       367358864
# avg_timediff           []
# has_zero                0
# Name: 336202, dtype: object
# source_id       367358920
# avg_timediff           []
# has_zero                0
# Name: 336209, dtype: object
# source_id       367359562
# avg_timediff           []
# has_zero                0
# Name: 336263, dtype: object
# source_id       367360054
# avg_timediff           []
# has_zero                0
# Name: 336280, dtype: object
# source_id       367362312
# avg_timediff           []
# has_zero                0
# Name: 336382, dtype: object
# source_id       367380609
# avg_timediff           []
# has_zero                0
# Name: 336468, dtype: object
# source_id       367380825
# avg_timediff           []
# has_zero                0
# Name: 336518, dtype: object
# source_id       367380954
# avg_timediff           []
# has_zero                0
# Name: 336528, dtype: object
# source_id       367380958
# avg_timediff           []
# has_zero                0
# Name: 336530, dtype: object
# source_id       367380959
# avg_timediff           []
# has_zero                0
# Name: 336531, dtype: object
# source_id       367381707
# avg_timediff           []
# has_zero                0
# Name: 336537, dtype: object
# source_id       367382640
# avg_timediff           []
# has_zero                0
# Name: 336596, dtype: object
# source_id       367384638
# avg_timediff           []
# has_zero                0
# Name: 336684, dtype: object
# source_id       367409320
# avg_timediff           []
# has_zero                0
# Name: 336846, dtype: object
# source_id       367409827
# avg_timediff           []
# has_zero                0
# Name: 336883, dtype: object
# source_id       367409978
# avg_timediff           []
# has_zero                0
# Name: 336888, dtype: object
# source_id       367410119
# avg_timediff           []
# has_zero                0
# Name: 336894, dtype: object
# source_id       367410129
# avg_timediff           []
# has_zero                0
# Name: 336898, dtype: object
# source_id       367410243
# avg_timediff           []
# has_zero                0
# Name: 336908, dtype: object
# source_id       367410852
# avg_timediff           []
# has_zero                0
# Name: 336927, dtype: object
# source_id       367410903
# avg_timediff           []
# has_zero                0
# Name: 336929, dtype: object
# source_id       367410974
# avg_timediff           []
# has_zero                0
# Name: 336930, dtype: object
# source_id       367410975
# avg_timediff           []
# has_zero                0
# Name: 336931, dtype: object
# 325262 10817

# %%
events_diff
# Out:
#         source_id                                       avg_timediff  has_zero
# 0        10002014  [1297 days, 6:03:45, 0:00:00, 0:00:00, 0:00:00...         1
# 1       100198211  [749 days, 18:37:17, 0:00:00, 0:00:00, 0:00:00...         1
# 2        10025396                              [1701 days, 22:45:47]         0
# 3        10025573                              [1701 days, 21:35:13]         0
# 4        10051516  [1376 days, 15:10:01, 0:00:00, 0:00:00, 0:00:0...         1
# ...           ...                                                ...       ...
# 336977  367464545                                          [0:00:00]         1
# 336978    4119647                              [4554 days, 21:49:58]         0
# 336979   79771482                                [697 days, 0:52:25]         0
# 336980    8060235                               [1627 days, 1:43:27]         0
# 336981    8291682                              [1609 days, 16:08:00]         0
#
# [336982 rows x 3 columns]
