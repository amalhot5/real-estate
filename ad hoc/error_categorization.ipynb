# %%
import pandas as pd

# %%
missing_fields = pd.read_csv('data/Sotheby\'s Missing Required FIelds - Sotheby Missing Fields.csv')
missing_fields.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 missing_fields = pd.read_csv('data/Sotheby\'s Missing Required FIelds - Sotheby Missing Fields.csv')
#       2 missing_fields.head()
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: "data/Sotheby's Missing Required FIelds - Sotheby Missing Fields.csv"

# %%
error = "CoListAgent Office of associated Members must, CoExclusiveAgentKey is required when ListingAgreement is CoExclusive, CoExclusiveOfficeKey is required when ListingAgreement is CoExclusive, FireplaceFeatures is required if FireplaceYN is True or FireplacesTotal is greater than 0"

# %%
error.split(', ')
# Out:
# ['CoListAgent Office of associated Members must',
#  'CoExclusiveAgentKey is required when ListingAgreement is CoExclusive',
#  'CoExclusiveOfficeKey is required when ListingAgreement is CoExclusive',
#  'FireplaceFeatures is required if FireplaceYN is True or FireplacesTotal is greater than 0']

# %%
error_list = error.split(', ')
flist = []
for e in error_list:
    tmp_lst = e.split()[:2]
    if tmp_lst[1][0].isupper():
        flist.append(" ".join(tmp_lst))
    else:
        flist.append(tmp_lst[0])
flist
# Out:
# ['CoListAgent Office',
#  'CoExclusiveAgentKey',
#  'CoExclusiveOfficeKey',
#  'FireplaceFeatures']

# %%
def create_key(error):
    error_list = error.split(', ')
    flist = []
    for e in error_list:
        tmp_lst = e.split()[:2]
        if tmp_lst[1][0].isupper():
            flist.append(" ".join(tmp_lst))
        else:
            flist.append(tmp_lst[0])
    return '|'.join(flist)

# %%
missing_fields['error_key'] = [create_key(x) for x in missing_fields['Error messages']]

# %%
all_keys = []
for k in missing_fields['error_key']:
    all_keys += (k.split('|'))
all_keys = set(all_keys)

# %%
stats = {'missing_field': [], 'num_listings': []}
for k in all_keys:
    count = 0
    for i in missing_fields['error_key']:
        if k in i:
            count += 1
    stats['missing_field'].append(k)
    stats['num_listings'].append(count)

# %%
stats = pd.DataFrame(stats)
stats
# Out:
#                missing_field  num_listings
# 0          PropertyCondition            33
# 1          BuildingAreaUnits            43
# 2            BuyerOfficeName             1
# 3         FurnishedListPrice             1
# 4             AttendanceType            26
# 5            BuyerAgentEmail             1
# 6                     TaxLot            40
# 7               LotSizeUnits            50
# 8         CoListAgent Office             1
# 9           ListingAgreement            49
# 10       ShowingInstructions             1
# 11         BuildingAreaTotal            43
# 12   FurnishedMinLeaseMonths            25
# 13   FurnishedMaxLeaseMonths            25
# 14            SizeDimensions            50
# 15                LivingArea             3
# 16          OwnerPaysRemarks             1
# 17          ListAgent Office             2
# 18         FireplaceFeatures           103
# 19        BuyerAgentLastName             1
# 20       BuyerAgentFirstName             1
# 21       CoExclusiveAgentKey            23
# 22                StreetName             3
# 23  SpecialListingConditions            69
# 24                  TaxBlock            93
# 25  BuyerAgentPreferredPhone             1
# 26                UnitNumber             1
# 27      PurchaseContractDate             3
# 28          BuyerOfficePhone             1
# 29      CoExclusiveOfficeKey            23
# 30     BuyerAgentOfficePhone             1
# 31            NumberOfShares            71
# 32        BuyerAgentFullName             1
# 33          AvailabilityDate             2
# 34                 MemberKey             9
# 35          CoBrokeAgreement            70

# %%
def report_writer(dfs:dict, report_name:str):
    """Creates an excel report using a dictionary of dfs.

    Args:
        dfs (dict): Data
        report_name (str): Name of file.
    """
    writer = pd.ExcelWriter(report_name, engine='xlsxwriter')
    workbook = writer.book
    format = workbook.add_format()
    format.set_align('center')
    for sheetname, df in dfs.items():
        df.to_excel(writer, sheet_name=sheetname, index=False)
        worksheet = writer.sheets[sheetname]
        for idx, col in enumerate(df):
            series =df[col]
            max_len = max((
                series.astype(str).map(len).max(),
                len(str(series.name))
            ))+1
            worksheet.set_column(idx, idx, max_len, format)

    writer.close()

# %%
report_writer({'errors_with_keys': missing_fields, 'summary_stats': stats}, 'data/sothebys_errors_with_summary.xlsx')

# %%
df_troy = pd.read_csv('perchwell_rls_listings.csv')
df_me = pd.read_csv('All_Perchwell_RLS_Listings_-_Troy_2024_02_09.csv')
df_troy.head()
# Out:
#      Price  Original Price            Property Type        Status  \
# 0  4025087       4735000.0                    Condo          Sold
# 1  4406931       4925000.0                    Condo          Sold
# 2  6417975      21250000.0                    Condo          Sold
# 3   740000        735000.0                    Co-op          Sold
# 4  7650000      22900000.0  Single-Family Townhouse  Perm Off Mkt
#
#                    List Date              Contract Date  DOM  \
# 0  2017-09-19 00:00:00 -0400  2018-02-21 08:59:42 -0500  156
# 1  2017-11-15 00:00:00 -0500  2018-03-05 14:00:53 -0500  111
# 2  2017-01-25 00:00:00 -0500  2018-05-21 00:00:00 -0400  482
# 3  2017-11-28 00:00:00 -0500  2017-12-14 14:51:05 -0500   17
# 4  2018-04-17 00:00:00 -0400  2015-09-11 13:31:05 -0400  414
#
#                                    Perchwell Link   Borough  \
# 0  https://www.perchwell.com/results#listing/6RRL  New York
# 1  https://www.perchwell.com/results#listing/6RWz  New York
# 2  https://www.perchwell.com/results#listing/9Q9Y  New York
# 3  https://www.perchwell.com/results#listing/jZ25  New York
# 4  https://www.perchwell.com/results#listing/lx6j  New York
#
#                 Address  ...       Third Agent Email Third Agent Phone  Beds  \
# 0  252 East 57th Street  ...  elorenzo@stribling.com      917-420-0104   3.0
# 1  252 East 57th Street  ...    ssmith@stribling.com      917-750-3047   3.0
# 2  252 East 57th Street  ...  elorenzo@stribling.com      917-420-0104   3.0
# 3  333 East 53rd Street  ...                     NaN               NaN   1.0
# 4   313 West 4th Street  ...  clr@lesliegarfield.com      212-574-6962   5.0
#
#    Baths Rooms    SQFT Commission Commission Total            Expiration Date  \
# 0    3.0   5.0  1929.0        4.0              4.0  2019-09-19 00:00:00 -0400
# 1    3.0   5.0  2016.0        4.0              4.0  2019-11-15 00:00:00 -0500
# 2    3.0   5.0  2246.0        4.0              4.0  2019-09-25 00:00:00 -0400
# 3    1.0   3.0   780.0        3.0              6.0  2018-05-15 00:00:00 -0400
# 4    4.0  10.0  5300.0        2.5              NaN  2020-12-30 19:00:00 -0500
#
#                                              RLS URL
# 0  https://rls.perchwell.com/audit/listings?q%5Bl...
# 1  https://rls.perchwell.com/audit/listings?q%5Bl...
# 2  https://rls.perchwell.com/audit/listings?q%5Bl...
# 3  https://rls.perchwell.com/audit/listings?q%5Bl...
# 4  https://rls.perchwell.com/audit/listings?q%5Bl...
#
# [5 rows x 32 columns]

# %%
df_me.head()
# Out:
#        price  original_list_price property_type     status       list_date  \
# 0  1195000.0            1195000.0         Co-op  Withdrawn  16/09/15 04:00
# 1  3042476.0            3495000.0         Condo     Closed  31/01/17 05:00
# 2  3450000.0            3500000.0         Condo  Withdrawn  21/09/16 04:00
# 3  2400000.0            2400000.0         Condo     Closed  30/04/10 04:00
# 4  3791000.0            3791000.0         Condo     Closed  06/04/11 04:00
#
#     contract_date  days_on_market  \
# 0             NaN           242.0
# 1  04/06/18 04:00           526.0
# 2             NaN           806.0
# 3             NaN          4881.0
# 4             NaN          4579.0
#
#                                               pw_url    borough  \
# 0  https://www.corenyc.com/property/470-west-24th...  Manhattan
# 1  http://www.sothebyshomes.com/nyc/sales/0011129...  Manhattan
# 2  http://www.sothebyshomes.com/nyc/sales/0011107...  Manhattan
# 3  https://www.corenyc.com/property/141-fifth-ave...  Manhattan
# 4  https://www.corenyc.com/property/141-fifth-ave...  Manhattan
#
#                 address  ... third_agent_name third_agent_email  \
# 0  470 West 24th Street  ...              NaN               NaN
# 1  425 West 50th Street  ...              NaN               NaN
# 2  322 West 57th Street  ...              NaN               NaN
# 3      141 Fifth Avenue  ...              NaN               NaN
# 4      141 Fifth Avenue  ...              NaN               NaN
#
#    third_agent_phone bedrooms  bathrooms rooms lot_size_square_feet  \
# 0                NaN      1.0        1.0   3.5                  NaN
# 1                NaN      2.0        2.0   4.0                  NaN
# 2                NaN      2.0        2.0   4.0                  NaN
# 3                NaN      2.0        2.0   4.0                  NaN
# 4                NaN      2.0        2.0   4.0                  NaN
#
#   commission_amount commission_total expiration_date
# 0               2.5              NaN  26/05/17 04:00
# 1               4.0              NaN  10/09/18 04:00
# 2               2.5              NaN  07/09/18 04:00
# 3               2.5              NaN  20/11/17 05:00
# 4               2.5              NaN  20/03/18 04:00
#
# [5 rows x 32 columns]

# %%
print(df_troy.columns)
print(df_me.columns)
# Out:
# Index(['Price', 'Original Price', 'Property Type', 'Status', 'List Date',
#        'Contract Date', 'DOM', 'Perchwell Link', 'Borough', 'Address',
#        'Unit Number', 'Place Name', 'ID', 'Brokerage ID', 'Brokerage Name',
#        'First Agent Name', 'First Agent Email', 'First Agent Phone',
#        'Second Agent Name', 'Second Agent Email', 'Second Agent Phone',
#        'Third Agent Name', 'Third Agent Email', 'Third Agent Phone', 'Beds',
#        'Baths', 'Rooms', 'SQFT', 'Commission', 'Commission Total',
#        'Expiration Date', 'RLS URL'],
#       dtype='object')
# Index(['price', 'original_list_price', 'property_type', 'status', 'list_date',
#        'contract_date', 'days_on_market', 'pw_url', 'borough', 'address',
#        'unit_number', 'place_name', 'id', 'mls_id', 'brokerage_id',
#        'brokerage', 'first_agent_name', 'first_agent_email',
#        'second_agent_phone', 'second_agent_name', 'first_agent_email1',
#        'second_agent_phone2', 'third_agent_name', 'third_agent_email',
#        'third_agent_phone', 'bedrooms', 'bathrooms', 'rooms',
#        'lot_size_square_feet', 'commission_amount', 'commission_total',
#        'expiration_date'],
#       dtype='object')

# %%
df_troy.drop(columns=['Perchwell Link', 'RLS URL'], inplace=True)
df_me.drop(columns=['pw_url', 'mls_id'], inplace=True)
df_me.columns = df_troy.columns

# %%
df_me.columns
# Out:
# Index(['Price', 'Original Price', 'Property Type', 'Status', 'List Date',
#        'Contract Date', 'DOM', 'Borough', 'Address', 'Unit Number',
#        'Place Name', 'ID', 'Brokerage ID', 'Brokerage Name',
#        'First Agent Name', 'First Agent Email', 'First Agent Phone',
#        'Second Agent Name', 'Second Agent Email', 'Second Agent Phone',
#        'Third Agent Name', 'Third Agent Email', 'Third Agent Phone', 'Beds',
#        'Baths', 'Rooms', 'SQFT', 'Commission', 'Commission Total',
#        'Expiration Date'],
#       dtype='object')

# %%
df_troy.set_index('ID').compare(df_me.set_index('ID'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_troy.set_index('ID').compare(df_me.set_index('ID'))
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/frame.py:7850, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    7728 @doc(
#    7729     _shared_docs["compare"],
#    7730     """
#    (...)
#    7848     result_names: Suffixes = ("self", "other"),
#    7849 ) -> DataFrame:
# -> 7850     return super().compare(
#    7851         other=other,
#    7852         align_axis=align_axis,
#    7853         keep_shape=keep_shape,
#    7854         keep_equal=keep_equal,
#    7855         result_names=result_names,
#    7856     )
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/generic.py:9216, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    9211     cls_self, cls_other = type(self).__name__, type(other).__name__
#    9212     raise TypeError(
#    9213         f"can only compare '{cls_self}' (not '{cls_other}') with '{cls_self}'"
#    9214     )
# -> 9216 mask = ~((self == other) | (self.isna() & other.isna()))
#    9218 if not keep_equal:
#    9219     self = self.where(mask)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/frame.py:7579, in DataFrame._cmp_method(self, other, op)
#    7576 def _cmp_method(self, other, op):
#    7577     axis = 1  # only relevant for Series other case
# -> 7579     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7581     # See GH#4537 for discussion of scalar op behavior
#    7582     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~/anaconda3/envs/pw/lib/python3.10/site-packages/pandas/core/ops/__init__.py:289, in align_method_FRAME(left, right, axis, flex, level)
#     287             left, right = left.align(right, join="outer", level=level, copy=False)
#     288         else:
# --> 289             raise ValueError(
#     290                 "Can only compare identically-labeled DataFrame objects"
#     291             )
#     292 elif isinstance(right, ABCSeries):
#     293     # axis=1 is default for DataFrame-with-Series op
#     294     axis = left._get_axis_number(axis) if axis is not None else 1
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
len(df_me)
# Out:
# 38774

# %%
len(df_troy)
# Out:
# 38742

# %%
df_troy[~df_troy['ID'].isin(df_me['ID'])][['ID', 'Address']]
# Out:
# Empty DataFrame
# Columns: [ID, Address]
# Index: []

# %%
merged = df_me.merge(df_troy, how='inner', on='ID')

# %%
len(merged[(merged['Price_x'] != merged['Price_y']) & (merged['Price_y'] != 0)][['ID', 'Address_x', 'Address_y', 'Price_x', 'Price_y']])
# Out:
# 16

# %%
merged[(merged['Status_y'] != merged['Status_x']) & ~(merged['Status_x'].isin(['Withdrawn', 'Closed', 'Pending', 'Hold']))][['ID', 'Status_x', 'Status_y']]
# Out:
#             ID Status_x      Status_y
# 2129   7536585        0  Perm Off Mkt
# 15889  1405715      NaN  Perm Off Mkt
# 16665  3821371      498  Perm Off Mkt
# 27857  7753967  Expired        Active
# 37377  3821423      499  Perm Off Mkt

# %%
merged[(merged['Status_y'] != merged['Status_x']) & ~(merged['Status_x'].isin(['Withdrawn', 'Closed']))][['ID', 'Status_x', 'Status_y']]
# Out:
#             ID Status_x        Status_y
# 1227   3418409  Pending  Under Contract
# 1651   3785996  Pending  Under Contract
# 1663   3791757  Pending  Under Contract
# 1732   3828171  Pending  Under Contract
# 1817   3866333  Pending  Under Contract
# ...        ...      ...             ...
# 38543  7711912     Hold    Temp Off Mkt
# 38544  7718185     Hold    Temp Off Mkt
# 38616  7712619  Pending  Under Contract
# 38659  7716040     Hold    Temp Off Mkt
# 38660  7754569  Pending  Under Contract
#
# [783 rows x 3 columns]

# %%
merged[merged['Address_x'] != merged['Address_y']][['ID', 'Address_x', 'Address_y']]
# Out:
#             ID                               Address_x  \
# 3849   3743446                    Allée Des Eucalyptus
# 12797  3774784         The Jameses – US Virgin Islands
# 12867  3818199  Little Saint James – US Virgin Islands
# 12869  3819033   Great Saint James – US Virgin Islands
# 13151  7535118                         13658 Vía Flora
# 16176  3234461       22 Queen Anne’s Gate, Westminster
# 16177  3234473       22 Queen Anne’s Gate, Westminster
# 20631  3313308          16 Boulevard De L’observatoire
# 21025  3743434                    Sq. Mérimée Immeuble
# 24892  3234220                   Cap D’antibes - Villa
# 33317  3746664     Provençal style property in Mougins
#
#                                       Address_y
# 3849                      AllÃ©e Des Eucalyptus
# 12797         The Jameses â€“ US Virgin Islands
# 12867  Little Saint James â€“ US Virgin Islands
# 12869   Great Saint James â€“ US Virgin Islands
# 13151                          13658 VÃ­a Flora
# 16176       22 Queen Anneâ€™s Gate, Westminster
# 16177       22 Queen Anneâ€™s Gate, Westminster
# 20631          16 Boulevard De Lâ€™observatoire
# 21025                    Sq. MÃ©rimÃ©e Immeuble
# 24892                   Cap Dâ€™antibes - Villa
# 33317      ProvenÃ§al style property in Mougins

# %%
merged
