# %%
import pandas as pd 

df = pd.read_csv('cincy_listings_sample.csv')
df['data'][0]
# Out:
# '{"Gas": "None", "URL": "http://cincy.rapmls.com/scripts/mgrqispi.dll?APPNAME=Cincynky&PRGNAME=MLSLogin&ARGUMENT=v0aUOXzzfsPHhuUrYk77bGAO0c6ocdULbG30hyuAOfs=&KeyRid=1", "City": "Clarksville", "Unit": "13", "View": "Woods,Valley", "Sewer": "None", "Suburb": "Clinton Co.", "Wooded": "Partly", "Zoning": "Residential", "Auction": "No", "ListAOR": "Cincinnati Area Multiple Listing Service", "Vacancy": 0.00, "Easement": "Of Record", "FIPSCode": 27, "Frontage": 200.00, "Latitude": 0.000000, "OnMarket": false, "SubLease": "No", "Township": "Adams", "Vacancy1": 0.00, "Bathrooms": 0.00, "CloseDate": "1994-08-09", "Financing": "Conventional", "Frontage1": 200.00, "ListPrice": 30000.00, "ListingId": "477550", "Longitude": 0.000000, "MLSOrigin": "Cincy", "MlsStatus": "Sold", "Occupancy": "At Closing", "SuburbSIC": "Clarksville", "Validated": true, "YearBuilt": 9999, "ClosePrice": 30000.00, "Directions": "So St Rt 123 Lt 22/3 Rt Clarksville Rd Lt St Rt 350 Rt Pyle Rd To Lot", "Disclaimer": "Inform
# ...

# %%
import json
json.loads(df['data'][0])
# Out:
# {'Gas': 'None',
#  'URL': 'http://cincy.rapmls.com/scripts/mgrqispi.dll?APPNAME=Cincynky&PRGNAME=MLSLogin&ARGUMENT=v0aUOXzzfsPHhuUrYk77bGAO0c6ocdULbG30hyuAOfs=&KeyRid=1',
#  'City': 'Clarksville',
#  'Unit': '13',
#  'View': 'Woods,Valley',
#  'Sewer': 'None',
#  'Suburb': 'Clinton Co.',
#  'Wooded': 'Partly',
#  'Zoning': 'Residential',
#  'Auction': 'No',
#  'ListAOR': 'Cincinnati Area Multiple Listing Service',
#  'Vacancy': 0.0,
#  'Easement': 'Of Record',
#  'FIPSCode': 27,
#  'Frontage': 200.0,
#  'Latitude': 0.0,
#  'OnMarket': False,
#  'SubLease': 'No',
#  'Township': 'Adams',
#  'Vacancy1': 0.0,
#  'Bathrooms': 0.0,
#  'CloseDate': '1994-08-09',
#  'Financing': 'Conventional',
#  'Frontage1': 200.0,
#  'ListPrice': 30000.0,
#  'ListingId': '477550',
#  'Longitude': 0.0,
#  'MLSOrigin': 'Cincy',
#  'MlsStatus': 'Sold',
#  'Occupancy': 'At Closing',
#  'SuburbSIC': 'Clarksville',
#  'Validated': True,
#  'YearBuilt': 9999,
#  'ClosePrice': 30000.0,
# ...
