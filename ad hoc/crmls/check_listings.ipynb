# %%
import pandas as pd

# %%
ids_to_check = ['1440026',
'1523370',
'1526104',
'1527329',
'1528462',
'1528464',
'1530790',
'1530791',
'1537521',
'1542150',
'1545553',
'1577672',
'1599162',
'1607540',
'1610216',
'1627045',
'1633230',
'1650712',
'1651257',
'1654478',
'1654481',
'1663570',
'1665792',
'1666472',
'1677983',
'1678896',
'1682706',
'1683197',
'1683214',
'1691350',
'1697279',
'1718813',
'1726397',
'1729846',
'1732770',
'1765852',
'1765859',
'1765866',
'1765868',
'1765870',
'1770436',
'1779355']

# %%
df = pd.read_csv('889140_2023_11_01.csv')
df.head()
# Out:
#        feed_name  source_id object_type  \
# 0  ca_crmls_rets    1542150     LISTING
# 1  ca_crmls_rets    1545553     LISTING
# 2  ca_crmls_rets    1577672     LISTING
# 3  ca_crmls_rets    1607540     LISTING
# 4  ca_crmls_rets    1770436     LISTING
#
#                                                 data  \
# 0  {'City': 'RSM', 'Roof': 'TLE', 'View': 'NO', '...
# 1  {'City': 'WTM', 'SpaYN': '1', 'Levels': 'A', '...
# 2  {'City': 'OKP', 'SpaYN': '1', 'Levels': 'A', '...
# 3  {'City': 'LA', 'View': 'NO', 'Sewer': 'UNK', '...
# 4  {'City': 'OSOS', 'Roof': 'CON', 'View': 'NO', ...
#
#                             data_hash      created_at       last_seen
# 0  \xd996b1106e43b85df5216c44a3a005c8  10/10/23 21:53  10/10/23 21:53
# 1  \x1df2f8f984a89486ea477da839716234  10/10/23 21:53  10/10/23 21:53
# 2  \xe6477cb652a6f36043bd1b97c228bc66  10/10/23 21:53  10/10/23 21:53
# 3  \x46bdf9c1c35dcdcc801422f5d0c208c9  10/10/23 21:54  10/10/23 21:54
# ...

# %%
df[~df['source_id'].isin(ids_to_check)]
# Out:
#          feed_name  source_id object_type  \
# 0    ca_crmls_rets    1542150     LISTING
# 1    ca_crmls_rets    1545553     LISTING
# 2    ca_crmls_rets    1577672     LISTING
# 3    ca_crmls_rets    1607540     LISTING
# 4    ca_crmls_rets    1770436     LISTING
# ..             ...        ...         ...
# 118  ca_crmls_rets    1765852     HISTORY
# 119  ca_crmls_rets    1765859     HISTORY
# 120  ca_crmls_rets    1765868     HISTORY
# 121  ca_crmls_rets    1770436     HISTORY
# 122  ca_crmls_rets    1530791     LISTING
#
#                                                   data  \
# 0    {'City': 'RSM', 'Roof': 'TLE', 'View': 'NO', '...
# 1    {'City': 'WTM', 'SpaYN': '1', 'Levels': 'A', '...
# 2    {'City': 'OKP', 'SpaYN': '1', 'Levels': 'A', '...
# 3    {'City': 'LA', 'View': 'NO', 'Sewer': 'UNK', '...
# 4    {'City': 'OSOS', 'Roof': 'CON', 'View': 'NO', ...
# ..                                                 ...
# 118  {'NewValue': '415000', 'ClassName': 'Residenti...
# ...
